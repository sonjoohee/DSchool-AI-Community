# %%
# %pip install customized-koNLPy
# Out:
# Requirement already satisfied: customized-koNLPy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.0.64)
# Requirement already satisfied: Jpype1>=0.6.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from customized-koNLPy) (1.5.0)
# Requirement already satisfied: konlpy>=0.4.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from customized-koNLPy) (0.6.0)
# Requirement already satisfied: packaging in /Users/star7/Library/Python/3.12/lib/python/site-packages (from Jpype1>=0.6.1->customized-koNLPy) (23.2)
# Requirement already satisfied: lxml>=4.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from konlpy>=0.4.4->customized-koNLPy) (5.1.0)
# Requirement already satisfied: numpy>=1.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from konlpy>=0.4.4->customized-koNLPy) (1.26.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
#반복문의 진행 상황을 시각적으로 표시 가능
# %pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (4.66.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json

#from konlpy.tag import Okt, Komoran, Kkma
from ckonlpy.tag import Twitter
from gensim.models import Doc2Vec # gensim의 doc2vec을 사용해 수치적 표현으로 변환하는 것을 목푲
from gensim.models.doc2vec import TaggedDocument
from gensim.models.callbacks import CallbackAny2Vec #모델 트레이닝 과정 모니터링 
from sklearn.metrics.pairwise import cosine_similarity #유사도 측정 
import numpy as np
from tqdm import tqdm
import os  # 모델이나 데이터 구조 저장 및 로드 
import pickle # 모델이나 데이터 구조 저장 및 로드 
import pandas as pd

# %%
# 데이터 경로 설정
data_path = './items.json'

# %%
# 데이터 로드 후 데이터프레임 확인
df = pd.read_json(data_path)

# %%
# '_source' 키를 통해 데이터프레임 생성
#normalize:  정규화
df = pd.json_normalize(df['_source']) #엘라스틱의 검색 인덱스가 _soucre 아래에 저장된 데이터를 포함

# %%
tokenizer = Twitter()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/konlpy/tag/_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
#연속된 문자열 제거. 
#ㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎ ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 이런 문자로 인해 kkma()런타임 오류남
def remove_consecutive_words(s): # 연속해서 3번이상 반복되는 문자열 제거 반혼 'aaabbb' -> aabbc'
    result = [] 
    count = 1  

    if s:
        result.append(s[0])

    for i in range(1, len(s)):
        if s[i] == s[i-1]:
            count += 1
        else:
            count = 1

        if count < 3:
            result.append(s[i])

    return ''.join(result)


#붙여쓴 문장을 강제로 분리하기. 길어지면 kkma()런타임 오류남
def insert_spaces(input_string, max_word_length=20):
    words = input_string.split()

    for i, word in enumerate(words):
        if len(word) >= max_word_length:
            split_words = [word[j:j+max_word_length] for j in range(0, len(word), max_word_length)]
            words[i] = '. '.join(split_words)

    result_string = ' '.join(words)
    return result_string



#토큰나이징 
# 토큰화 과정의 일부로서, 특정 문서나 문장을 토큰화하기 전에 필요한 사전 처리를 목적
def tokenizing(sentence):
    sentence = insert_spaces(sentence.lower())
    sentence = remove_consecutive_words(sentence)
    tokens = tokenizer.nouns(sentence)
    tokens = [x for x in tokens if len(x) > 1]
    tokens = [x for x in tokens if not x.isdigit()]
    return tokens

# TaggedDocument 형태로 변환하는 함수
#dataFrame의 각 행을 순회하며, item_idx 및 contents 열의 데이터를 사용하여 처리를 수행하도록 설계
#특정 칼럼의 텍스트 데이터를 형태소 분석하여 토큰화 한 다음, 이를 TaggedDocument 객체로 만드는 과정을 수행합니다. 
#여기서 TaggedDocument는 Doc2Vec 모델 학습에 사용되는 데이터 구조로, 각 문서(또는 문장)의 단어 리스트와 해당 문서에 할당된 태그(식별자)를 포함합
def tag_sentences_from_df(df): # 데이터프레임을 인자로 받는다 
    tagged_data = []
    for _, row in df.iterrows():
        item_idx = row['item_idx']  # 각 문서에 대한 고유 ID를 변수에 저장
        processed_text = row['combined']  # 전처리된 문서 내용을 변수에 저장
        
        if not processed_text:
            continue
        tokens = tokenizing(processed_text)  # 전처리된 텍스트를 토큰화
        tagged_data.append(TaggedDocument(words=tokens, tags=[f"{item_idx}"]))
    return tagged_data

#tagged_data : 각 문서의 토큰화된 단어들(words)과 각 문서를 구볋할 수 있는 식별자 (tags)를 포함하는 taggedocument 객체들의 리스트

# %%
with open("user_dictionary_stringify.txt", 'r', encoding='utf-8') as file:
    user_dict = file.read().split(",")

user_dict = sorted(user_dict, key=len, reverse=True)

for word in user_dict:
    tokenizer.add_dictionary(word, 'Noun')

# %%
# DataFrame에 'combined' 열 추가
df['combined'] = df.apply(lambda row: row["subject"] + " " + row["contents"], axis=1) 

# 텍스트 데이터 전처리
# 'combined' 열에 대해 연속된 문자열 제거 및 필터링 수행
df['combined'] = df['combined'].apply(remove_consecutive_words)
# 길이가 300자를 초과한다면 그 항목을 300자까지로 자름. 60자 이하라면 none으로 설정
df['combined'] = df['combined'].apply(lambda x: x[:300] if len(x) > 60 else None) 

# 필터링된 데이터만 유지
df = df.dropna(subset=['combined'])



# Doc2Vec 모델 학습 데이터 준비
if not os.path.exists("doc2vec_corpus2.pkl"):
    tagged_data = tag_sentences_from_df(df[['item_idx', 'combined']]) # 데이터프레임 유지
    with open("doc2vec_corpus2.pkl", "wb") as file:  # 파일 이름 오타 수정
        pickle.dump(tagged_data, file)
else:
    with open("doc2vec_corpus2.pkl", "rb") as file:
        tagged_data = pickle.load(file)

# %%
print(df.columns)
# Out:
# Index(['item_idx', 'subject', 'contents', 'author_nick', 'created_at',
#        'replies', 'combined', 'vector'],
#       dtype='object')

# %%
# DataFrame의 처음 5행을 출력합니다.
print(df.head())
# Out:
#    item_idx                 subject  \
# 0      4561        토토로와 그녀의 청담동 나들이
# 1      5684   ILE와 PEAI 입학시험 체험기...
# 2       191                아들아 보거라.
# 3      7408  이안어학원 영역별 수강시스템 괜찮을까요?
# 4      8194    공부밖에 몰랐던 전교1등 이야기 #6
#
#                                             contents author_nick  \
# 0  청담安 이라고 들어보셨나요 ?이미 많이 알려진 강남의 명소로 개그맨(?) 윤정수씨가...         백지수
# 1  제가 대치동에 오기 전에는 들어가기 힘든 순서가 렉스킴&gt;피아이&gt;아이엘이로...         박혀하
# 2  한미은행장이 아들에게 보낸 편지입니다.공감을 주는 내용이 많아서 인터넷에 회자되었던...         양유성
# 3  예비중1 이안어학원에 대한 들리는 평판이 좋기도 했고, 또 마침 아이시간표 조절할일...         류태근
# 4  아이템풀과 구몬수학  누군가 인생은 괴로움의 연속이라고 했던가. 원이형도 같은 반 ...         김재재
#
#             created_at                                            replies  \
# 0  2009-08-08 18:44:45  [1. 저 데이트에 끼고 싶습니다.2. 혹시 설마 오렌지족이셨습니까?3. 믿고 의지...
# 1  2009-11-13 06:54:20  [글쎄...저도 ILE가봤는데 저희아이는 5학년이라 그런지 모르겠지만 모든 게 다 ...
# 2  2008-08-26 09:56:50  [좋은글을 많이 만나봤지만 우리들 모두에게 마음으로 필요한 말인것같아 넘 감사드립니...
# 3  2010-02-09 21:40:03  [저는 영어종합반 보다는 영역별 개설 강좌를 매우 선호합니다. 중1이라면 말하기는 ...
# 4  2010-03-22 18:26:07  [글을 읽으니 고1아들둔 엄마로서 한숨이 절로 나오네요... 열심히 공부하지 않는 ...
#
#                                             combined  \
# 0  토토로와 그녀의 청담동 나들이 청담安 이라고 들어보셨나요 ?이미 많이 알려진 강남의...
# 1  ILE와 PEAI 입학시험 체험기.. 제가 대치동에 오기 전에는 들어가기 힘든 순서...
# 2  아들아 보거라. 한미은행장이 아들에게 보낸 편지입니다.공감을 주는 내용이 많아서 인...
# 3  이안어학원 영역별 수강시스템 괜찮을까요? 예비중1 이안어학원에 대한 들리는 평판이 ...
# 4  공부밖에 몰랐던 전교1등 이야기 #6 아이템풀과 구몬수학  누군가 인생은 괴로움의 ...
#
#                                               vector
# 0  [0.6086013, 0.47499812, -0.26751295, -0.116748...
# 1  [0.39927167, -0.34114057, -0.73800105, 0.56053...
# 2  [-0.0073037115, -0.2437775, 0.25304675, 0.7326...
# 3  [0.3709748, 0.50565994, -1.1514426, 0.04925793...
# 4  [-0.5066662, 0.007347686, 0.16918911, 1.210750...

# %%
print(df.tail())
# Out:
#         item_idx                                            subject  \
# 122440    545008  중등아이가 친구랑놀다가 4번째손가락을 골절되었는데요이동네 정형외과에 가서 손가락 기...
# 122441    544947  초5 생크 중학과정하는데..개념원리 일품 최상위 3권해요. 그런데..이게 숙제하느라...
# 122442    544919  중2사춘기에 접어든거같은데요모두알아서 한다고 해서 학원숙제 조금하고 간게2주고 그뒤...
# 122444    545102  올해 입학한 대학생 딸아이가 있어요. 그동안은 성격이 지랄맞긴해도 관계가 나쁘진 않...
# 122445    545095  친구가 저더러 자식하고 감정분리가 안되는게 문제라고 합니다. 친구는 외국에서 아이들...
#
#                                                  contents author_nick  \
# 122440  중등아이가 친구랑놀다가 4번째손가락을 골절되었는데요이동네 정형외과에 가서 손가락 기...         권웅원
# 122441  초5 생크 중학과정하는데..개념원리 일품 최상위 3권해요. 그런데..이게 숙제하느라...         김미하
# 122442  중2사춘기에 접어든거같은데요모두알아서 한다고 해서 학원숙제 조금하고 간게2주고 그뒤...         오상타
# 122444  올해 입학한 대학생 딸아이가 있어요. 그동안은 성격이 지랄맞긴해도 관계가 나쁘진 않...         이재면
# 122445  친구가 저더러 자식하고 감정분리가 안되는게 문제라고 합니다. 친구는 외국에서 아이들...         백산재
#
#                  created_at  \
# 122440  2023-08-12 13:19:18
# 122441  2023-08-12 07:27:21
# 122442  2023-08-11 22:00:15
# 122444  2023-08-12 23:31:40
# 122445  2023-08-12 22:48:22
#
#                                                   replies  \
# 122440  [그래서 처음에 끝마디를 기브스를 안해서 바로안붙고 잘못붙었나봐요, 의사가 2주 있...
# 122441  [문제집 오답은 필요하면 따로 해야 해요.틀린문제 숙제하면서 다시 풀지 않나요?다시...
# 122442  [저도 많이 힘들었어요 1년 넘게 가방만 들고 다니네요. 학원 넣어놓으면 뛰쳐나오길...
# 122444  [고3 아들인데 아빠오면 공부하다가도 나와서 인사합니다. 그렇게 가르쳤어요. 부모 ...
# 122445  [그런 쿨병도 너무 싫어요.부모가 자식의 진로를 고민하면 그게 굉장히 문제있는것처럼...
#
#                                                  combined  \
# 122440  중등아이가 친구랑놀다가 4번째손가락을 골절되었는데요이동네 정형외과에 가서 손가락 기...
# 122441  초5 생크 중학과정하는데..개념원리 일품 최상위 3권해요. 그런데..이게 숙제하느라...
# 122442  중2사춘기에 접어든거같은데요모두알아서 한다고 해서 학원숙제 조금하고 간게2주고 그뒤...
# 122444  올해 입학한 대학생 딸아이가 있어요. 그동안은 성격이 지랄맞긴해도 관계가 나쁘진 않...
# 122445  친구가 저더러 자식하고 감정분리가 안되는게 문제라고 합니다. 친구는 외국에서 아이들...
#
#                                                    vector
# 122440  [1.1912905, 0.058996793, -0.206127, 0.43094155...
# 122441  [-0.21351588, -0.18485914, -0.37671673, -0.072...
# 122442  [0.27543083, 0.64377177, -0.079306595, 0.53197...
# 122444  [-0.18672772, -0.20815891, -0.27428073, -0.264...
# 122445  [0.021963049, 0.57581437, -0.6052079, 0.650434...

# %%
# len 함수를 사용하여 행의 수 확인
print(len(df))

# shape 속성의 첫 번째 요소를 사용하여 행의 수 확인
print(df.shape[0])
# Out:
# 82119
# 82119

# %%
missing_values_count = df.isnull().sum()

# 각 열별로 누락된 값의 개수 출력
print(missing_values_count)

# 전체 데이터 프레임에서 누락된 값의 총합 출력
total_missing_values = missing_values_count.sum()
print(f"데이터 프레임 전체에서 누락된 값의 총 개수: {total_missing_values}")
# Out:
# item_idx       0
# subject        0
# contents       0
# author_nick    0
# created_at     0
# replies        0
# combined       0
# vector         0
# dtype: int64
# 데이터 프레임 전체에서 누락된 값의 총 개수: 0

# %%
#Doc2Vec 학습하기
model = Doc2Vec(vector_size=128, window=2, min_count=1, workers=4, epochs=300, sample=1e-5 , seed=42, alpha=0.01, min_alpha=0.0001)
 
model.build_vocab(tagged_data)  #단어사전 학습 

print("vocab 사이즈 : ", len(model.wv.index_to_key))  #단어사전의 크기
# Out:
# vocab 사이즈 :  50623

# %%
#단어 빈도수 확인
print("Word Frequencies:")
for word in model.wv.index_to_key:
    count = model.wv.get_vecattr(word, "count")
    print(f"Word {word}: {count}")
# Out:
# Word Frequencies:
# Word 아이: 62541
# Word 어요: 50677
# Word 학원: 43460
# Word 수학: 22107
# Word 수업: 20977
# Word 선생님: 17810
# Word 어서: 17780
# Word 내신: 17594
# Word 생각: 16652
# Word 영어: 16101
# Word 공부: 15772
# Word 정도: 15629
# Word 부탁: 15343
# Word 까지: 15325
# Word 학교: 15272
# Word 시간: 15020
# Word 학년: 14484
# Word 추천: 13898
# Word 문제: 12184
# Word 지금: 12161
# Word 부터: 11496
# Word 혹시: 11373
# Word 고민: 11284
# Word 엄마: 11103
# Word 면서: 10989
# Word 다른: 10891
# Word 시험: 10659
# Word 려고: 10320
# Word 수능: 10008
# Word 이번: 9860
# Word 저희: 9585
# Word 국어: 9584
# Word 드립: 9584
# Word 보고: 9306
# Word 하다: 9186
# Word 이나: 9011
# Word 오늘: 8931
# Word 고등: 8796
# Word 아들: 8751
# Word 해주: 8386
# Word 서요: 8342
# Word 하나: 8331
# Word 그냥: 8294
# Word 남편: 8218
# Word 중등: 8124
# Word 정말: 8121
# Word 다가: 8055
# Word 준비: 8037
# Word 어디: 7908
# Word 시작: 7845
# Word 가요: 7780
# Word 학생: 7771
# Word 고요: 7406
# Word 보다: 6926
# Word 고3: 6893
# Word 감사: 6814
# Word 이제: 6790
# Word 걱정: 6764
# Word 선택: 6741
# Word 더니: 6590
# Word 고1: 6580
# Word 한번: 6570
# Word 요즘: 6492
# Word 아보: 6409
# Word 중3: 6393
# Word 과학: 6340
# Word 선행: 6278
# Word 과목: 6242
# Word 성적: 6139
# Word 설명: 6088
# Word 대치동: 5986
# Word 병원: 5962
# Word 친구: 5892
# Word 던데: 5857
# Word 다시: 5745
# Word 대치: 5688
# Word 어가: 5642
# Word 아직: 5638
# Word 도움: 5612
# Word 조언: 5611
# Word 때문: 5591
# Word 방학: 5513
# Word 사람: 5480
# Word 계속: 5460
# Word 마음: 5311
# Word 디스쿨: 5244
# Word 현재: 5237
# Word 기도: 5147
# Word 심화: 5146
# Word 경우: 5096
# Word 중1: 5047
# Word 논술: 5041
# Word 대학: 5031
# Word 숙제: 4992
# Word 아무: 4931
# Word 혼자: 4906
# Word 과외: 4878
# Word 중2: 4857
# Word 점수: 4844
# Word 입시: 4843
# Word 수시: 4836
# Word 이과: 4823
# Word 특강: 4818
# Word 고2: 4815
# Word 학기: 4814
# Word 가능: 4795
# Word 진도: 4787
# Word 하니: 4749
# Word 처음: 4729
# Word 테스트: 4719
# Word 이사: 4661
# Word 아시: 4635
# Word 얘기: 4572
# Word 경험: 4571
# Word 여기: 4541
# Word 질문: 4536
# Word 어제: 4503
# Word 거의: 4485
# Word 예비고1: 4484
# Word 우리: 4481
# Word 어보: 4473
# Word 예비: 4411
# Word 자기: 4390
# Word 실력: 4379
# Word 관리: 4351
# Word 열심: 4322
# Word 레벨: 4293
# Word 인지: 4277
# Word 해도: 4260
# Word 선배: 4249
# Word 기본: 4208
# Word 하나요: 4182
# Word 초등: 4139
# Word 조금: 3981
# Word 중학교: 3974
# Word 과정: 3964
# Word 정보: 3954
# Word 개념: 3950
# Word 안녕: 3943
# Word 주시: 3934
# Word 문법: 3934
# Word 래서: 3928
# Word 남자: 3836
# Word 보신: 3816
# Word 강의: 3738
# Word 거나: 3697
# Word 건가: 3683
# Word 별로: 3682
# Word 디맘: 3674
# Word 지도: 3668
# Word 만원: 3652
# Word 시대: 3650
# Word 상담: 3631
# Word 모두: 3629
# Word 라서: 3610
# Word 머리: 3600
# Word 정시: 3584
# Word 아주: 3576
# Word 가야: 3540
# Word 일반: 3537
# Word 작년: 3523
# Word 필요: 3518
# Word 수학학원: 3475
# Word 처럼: 3466
# Word 입학: 3432
# Word 아침: 3416
# Word 교재: 3408
# Word 영어학원: 3398
# Word 이상: 3373
# Word 동네: 3371
# Word 올해: 3327
# Word 신가: 3315
# Word 문과: 3305
# Word 말씀: 3300
# Word 수준: 3261
# Word 아하: 3250
# Word 전화: 3244
# Word 마다: 3219
# Word 하루: 3208
# Word 근처: 3200
# Word 내용: 3200
# Word 미리: 3197
# Word 본인: 3195
# Word 서울: 3194
# Word 검색: 3179
# Word 인강: 3170
# Word 문의: 3160
# Word 의대: 3158
# Word 이야기: 3150
# Word 부분: 3129
# Word 나이: 3113
# Word 지원: 3113
# Word 갑자기: 3099
# Word 중인: 3066
# Word 가지: 3053
# Word 계시: 3033
# Word 어도: 3032
# Word 결과: 3022
# Word 을지: 3021
# Word 물리: 2956
# Word 수상: 2950
# Word 구들: 2922
# Word 대비: 2891
# Word 방법: 2880
# Word 대한: 2876
# Word 사실: 2852
# Word 얼마: 2836
# Word 깊생: 2829
# Word 코로나: 2815
# Word 부족: 2815
# Word 상태: 2813
# Word 이면: 2801
# Word 상황: 2782
# Word 가면: 2766
# Word 일단: 2758
# Word 진짜: 2709
# Word 합격: 2692
# Word 대형: 2691
# Word 강남: 2677
# Word 중간: 2670
# Word 보통: 2646
# Word 고등학교: 2639
# Word 신분: 2630
# Word 아파트: 2622
# Word 애가: 2621
# Word 어디가: 2603
# Word 동안: 2591
# Word 인재: 2585
# Word 서울대: 2584
# Word 학습: 2582
# Word 주변: 2568
# Word 대해: 2563
# Word 분위기: 2561
# Word 중이: 2560
# Word 검사: 2558
# Word 어찌: 2558
# Word 예정: 2551
# Word 바로: 2547
# Word 겨울방학: 2539
# Word 여행: 2520
# Word 전형: 2512
# Word 미국: 2501
# Word 모의고사: 2494
# Word 어머님: 2488
# Word 는걸: 2476
# Word 중간고사: 2469
# Word 신청: 2467
# Word 초6: 2464
# Word 님들: 2460
# Word 수술: 2454
# Word 여름: 2440
# Word 예전: 2433
# Word 남아: 2429
# Word 결정: 2427
# Word 화학: 2420
# Word 아래: 2403
# Word 오래: 2398
# Word 전혀: 2396
# Word 배정: 2392
# Word 시나: 2378
# Word 등급: 2351
# Word 여러: 2344
# Word 라가: 2338
# Word 등록: 2332
# Word 느낌: 2332
# Word 달라: 2331
# Word 여학생: 2323
# Word 보이: 2320
# Word 지나: 2317
# Word 개월: 2316
# Word ile: 2314
# Word 기간: 2312
# Word 대학생: 2292
# Word 사용: 2287
# Word 댓글: 2287
# Word 이구: 2278
# Word 피부: 2274
# Word 저녁: 2267
# Word 효과: 2263
# Word 려면: 2257
# Word 원래: 2245
# Word 관련: 2244
# Word 안나: 2236
# Word 한국: 2226
# Word 매일: 2213
# Word 부모님: 2211
# Word 여름방학: 2211
# Word 각하: 2199
# Word 정리: 2197
# Word 유명: 2196
# Word 하라: 2196
# Word 주말: 2177
# Word 수도: 2158
# Word 아야: 2148
# Word 얼굴: 2145
# Word 가족: 2141
# Word 지고: 2138
# Word 거리: 2126
# Word 가장: 2125
# Word 정석: 2119
# Word 학부모: 2101
# Word 예약: 2090
# Word 이해: 2089
# Word 최근: 2088
# Word 어학원: 2077
# Word 신경: 2075
# Word 진행: 2072
# Word 소리: 2068
# Word 1등급: 2067
# Word 남학생: 2056
# Word 문자: 2056
# Word 불안: 2054
# Word 편이: 2047
# Word 영재: 2046
# Word 위해: 2044
# Word 관심: 2034
# Word 운동: 2032
# Word 가격: 2031
# Word 겨울: 2020
# Word 이예: 2014
# Word 제일: 1998
# Word 내일: 1980
# Word 직장: 1980
# Word 중요: 1961
# Word 치료: 1951
# Word 연락: 1944
# Word 무슨: 1942
# Word 성실: 1935
# Word 이유: 1928
# Word 차이: 1928
# Word 둘째: 1917
# Word 배우: 1913
# Word 대요: 1908
# Word 생활: 1898
# Word 계획: 1887
# Word 자녀: 1885
# Word 미적: 1875
# Word 소개: 1875
# Word 모든: 1869
# Word 그동안: 1865
# Word 의견: 1847
# Word 수가: 1844
# Word 제대로: 1841
# Word 언제: 1836
# Word 다리: 1836
# Word 아빠: 1835
# Word 외고: 1835
# Word 재수: 1831
# Word 부하: 1830
# Word 내년: 1830
# Word 등등: 1819
# Word 나름: 1818
# Word 이후: 1814
# Word 교육: 1809
# Word 면접: 1797
# Word 딸아이: 1797
# Word 고하: 1795
# Word 목표: 1795
# Word 가보: 1792
# Word 여고: 1790
# Word 생기: 1779
# Word 지난: 1777
# Word 경기: 1766
# Word 결혼: 1766
# Word 토플: 1760
# Word 가기: 1757
# Word 지방: 1757
# Word 예비고3: 1755
# Word 다음: 1753
# Word 간다: 1747
# Word 황소: 1746
# Word 한지: 1743
# Word 스타일: 1743
# Word 대로: 1740
# Word gt: 1737
# Word 지역: 1731
# Word 리딩: 1726
# Word 해주시: 1725
# Word 보기: 1724
# Word 원장: 1718
# Word 안해: 1696
# Word 위주: 1695
# Word 스트레스: 1676
# Word 시기: 1666
# Word 여자: 1660
# Word 단어: 1659
# Word 자주: 1657
# Word 부담: 1653
# Word 자꾸: 1651
# Word 이동: 1644
# Word 언어: 1639
# Word 기하: 1638
# Word 다원: 1636
# Word 친정: 1632
# Word 얼마나: 1626
# Word 최상위: 1624
# Word 졸업: 1622
# Word 수하: 1622
# Word 컨설팅: 1617
# Word 먼저: 1616
# Word 상위권: 1615
# Word 정규: 1614
# Word 전부: 1613
# Word 물어: 1612
# Word 참고: 1612
# Word 여서: 1606
# Word 항상: 1605
# Word 난이도: 1600
# Word 대부분: 1595
# Word 선물: 1578
# Word 사이: 1569
# Word 평가: 1567
# Word 인원: 1565
# Word 의사: 1560
# Word 자신: 1560
# Word 자리: 1555
# Word 후기: 1554
# Word 일주일: 1541
# Word 이것: 1532
# Word 정신: 1529
# Word 집중: 1525
# Word 통과: 1522
# Word 자고: 1515
# Word 사춘기: 1514
# Word 사진: 1507
# Word 중학생: 1505
# Word 군데: 1501
# Word 문학: 1490
# Word 예비고2: 1480
# Word 부모: 1473
# Word 비교: 1468
# Word 원서: 1464
# Word 뭔가: 1463
# Word 이요: 1457
# Word 기분: 1453
# Word 전세: 1447
# Word 며칠: 1446
# Word 만큼: 1440
# Word 워낙: 1434
# Word 진학: 1434
# Word 죄송: 1419
# Word 개인: 1415
# Word 완전: 1407
# Word 강사: 1407
# Word 이지: 1402
# Word 대기: 1399
# Word 지인: 1398
# Word kns: 1393
# Word 자료: 1388
# Word 자사고: 1387
# Word 2등급: 1387
# Word 사고: 1384
# Word 아지: 1380
# Word 가끔: 1378
# Word 거기: 1370
# Word 은지: 1369
# Word 수강: 1369
# Word 기준: 1368
# Word 아가: 1362
# Word 기억: 1361
# Word 무엇: 1358
# Word 평소: 1353
# Word 지망: 1353
# Word 인터넷: 1352
# Word 확인: 1347
# Word 니지: 1344
# Word 드릴: 1339
# Word 본적: 1337
# Word 평균: 1332
# Word 전문: 1329
# Word 사회: 1326
# Word 주로: 1326
# Word 내야: 1316
# Word 커리: 1314
# Word 오전: 1313
# Word 이입: 1305
# Word 그때: 1303
# Word 불편: 1303
# Word 우선: 1301
# Word 까운: 1301
# Word 독서: 1301
# Word 재미: 1297
# Word 수리: 1293
# Word 려니: 1283
# Word 심해: 1275
# Word 의미: 1274
# Word 증상: 1270
# Word 해지: 1270
# Word 음식: 1268
# Word 소수: 1266
# Word 서도: 1262
# Word 보시: 1257
# Word 오후: 1249
# Word 답변: 1241
# Word 교정: 1241
# Word 이용: 1234
# Word 이름: 1233
# Word 잘못: 1231
# Word 어머니: 1230
# Word 가방: 1225
# Word 실수: 1224
# Word 라면: 1221
# Word 고생: 1218
# Word 신지: 1218
# Word 마지막: 1212
# Word 독해: 1212
# Word 겨우: 1207
# Word 나중: 1206
# Word 기출: 1198
# Word 지니: 1197
# Word 단계: 1195
# Word 스스로: 1192
# Word 회사: 1191
# Word 벌써: 1188
# Word 건강: 1181
# Word 대상: 1181
# Word 살짝: 1176
# Word 자식: 1174
# Word 일어: 1172
# Word 상하: 1167
# Word 전공: 1164
# Word 약간: 1156
# Word 성향: 1155
# Word 주신: 1153
# Word 추가: 1148
# Word 비용: 1145
# Word 여자아이: 1133
# Word 일정: 1132
# Word 안보: 1127
# Word 점점: 1126
# Word it: 1125
# Word 그나: 1119
# Word 그것: 1118
# Word 커피: 1117
# Word 외국: 1114
# Word 타고: 1112
# Word 내내: 1109
# Word 전학: 1107
# Word 담임: 1106
# Word 은마: 1105
# Word 함영원: 1103
# Word 모의: 1096
# Word 하자: 1096
# Word 음으로: 1096
# Word 영역: 1093
# Word 정확: 1090
# Word 생명: 1085
# Word 가슴: 1079
# Word 크게: 1071
# Word 구입: 1067
# Word 자체: 1066
# Word 발표: 1064
# Word 상관: 1061
# Word 직접: 1061
# Word 월부: 1055
# Word 성격: 1050
# Word 모임: 1046
# Word 아예: 1042
# Word 진로: 1042
# Word 자세: 1042
# Word 경시: 1041
# Word 기사: 1040
# Word 확실: 1040
# Word 중반: 1035
# Word 진료: 1035
# Word 치과: 1029
# Word 진선: 1027
# Word 능력: 1027
# Word 가게: 1020
# Word 궁금: 1020
# Word 프로: 1017
# Word 호텔: 1017
# Word 교과서: 1017
# Word 청담: 1014
# Word 더라도: 1013
# Word 데리: 1010
# Word 카드: 1008
# Word 텝스: 1007
# Word 다만: 1003
# Word 해외: 1003
# Word 3등급: 1002
# Word 고해: 1002
# Word 재수생: 1001
# Word 대충: 999
# Word 소규모: 999
# Word 사랑: 998
# Word 카페: 998
# Word 노력: 995
# Word 만족: 993
# Word 원수학: 993
# Word 점심: 991
# Word 생수: 990
# Word 교과: 990
# Word 언니: 990
# Word 온라인: 986
# Word 마치: 985
# Word 대입: 985
# Word 레테: 984
# Word 보험: 984
# Word 바람: 974
# Word 업체: 973
# Word 유학: 972
# Word 최선: 972
# Word 절대: 969
# Word 초등학교: 968
# Word 내시: 962
# Word 포기: 958
# Word 과고: 958
# Word 모습: 957
# Word 고딩: 955
# Word 세상: 954
# Word 도록: 954
# Word 누구: 954
# Word 이든: 953
# Word 고도: 952
# Word 가도: 951
# Word 기말고사: 948
# Word 연대: 945
# Word 서초: 943
# Word 역시: 943
# Word 시간표: 940
# Word 국제: 935
# Word 적응: 933
# Word 휘문고: 933
# Word 어진: 930
# Word 개별: 929
# Word 반포: 929
# Word 부부: 923
# Word 해결: 923
# Word 새벽: 919
# Word 유지: 919
# Word 삼성: 917
# Word 활동: 916
# Word 식사: 912
# Word 우울: 911
# Word 수험생: 911
# Word 포함: 910
# Word 후반: 909
# Word 만점: 903
# Word 일찍: 903
# Word 숙명: 901
# Word 서로: 901
# Word 프로그램: 900
# Word 중딩: 898
# Word 공대: 898
# Word 동생: 897
# Word 브랜드: 895
# Word 이건: 895
# Word 이하: 894
# Word 삼보: 892
# Word 미적분: 890
# Word 예비중1: 888
# Word 다지: 888
# Word 성적표: 886
# Word 백화점: 883
# Word 잡고: 882
# Word 골프: 879
# Word 종일: 878
# Word 마무리: 876
# Word 한티역: 876
# Word 범위: 871
# Word 병행: 870
# Word 생리: 869
# Word 듣기: 869
# Word 기대: 868
# Word ing: 868
# Word 아해: 868
# Word 한국사: 866
# Word 그게: 866
# Word 분석: 865
# Word 매번: 863
# Word 암기: 862
# Word 런가: 861
# Word 적당: 860
# Word 조카: 860
# Word 지하: 858
# Word cms: 857
# Word 상가: 856
# Word 만두: 855
# Word 고대: 853
# Word 저렴: 853
# Word 특별: 851
# Word 알바: 850
# Word 게임: 850
# Word 짜증: 849
# Word 조심: 844
# Word 청소: 841
# Word 말로: 841
# Word 모집: 841
# Word 여기저기: 839
# Word 에어컨: 838
# Word 안내: 838
# Word 공유: 838
# Word 장님: 837
# Word 오히려: 837
# Word 이도: 836
# Word 핸드폰: 835
# Word 다행: 835
# Word 나니: 834
# Word 막상: 833
# Word 제품: 832
# Word 기고: 826
# Word 클리: 825
# Word 닌지: 824
# Word 고학년: 824
# Word 고려: 822
# Word 단원: 821
# Word 통증: 821
# Word 주도: 819
# Word 그대로: 818
# Word 통해: 818
# Word 기초: 817
# Word 드라마: 817
# Word 관계: 816
# Word 처방: 815
# Word 어휘: 814
# Word 독서실: 813
# Word 허리: 813
# Word 연습: 812
# Word 전교: 810
# Word 방식: 809
# Word 욕심: 808
# Word 개강: 806
# Word 고교: 804
# Word 마감: 802
# Word 외국어: 802
# Word 냄새: 802
# Word 몇번: 799
# Word 표현: 797
# Word 유전: 793
# Word 주사: 792
# Word 이신: 792
# Word 최고: 790
# Word 만하: 789
# Word 누가: 788
# Word 눈물: 788
# Word 전체: 787
# Word 인생: 787
# Word 반복: 785
# Word 도곡: 784
# Word 사려: 780
# Word 무리: 780
# Word 고등학생: 776
# Word 방향: 776
# Word 먹이: 775
# Word 여드름: 774
# Word 강하: 773
# Word 잠깐: 773
# Word 끝내: 772
# Word 복습: 772
# Word 매우: 770
# Word 맛집: 769
# Word 솔직: 769
# Word 체적: 769
# Word 살이: 769
# Word 사서: 768
# Word 고자: 767
# Word 사하: 764
# Word 지네: 762
# Word 국영수: 761
# Word 요새: 761
# Word 사주: 761
# Word 미탐: 760
# Word 기전: 759
# Word 초반: 759
# Word 중심: 759
# Word 주차: 758
# Word 해하: 757
# Word in: 753
# Word 희망: 752
# Word 갈수: 751
# Word 친정엄마: 747
# Word 무조건: 747
# Word 가입: 742
# Word 접수: 742
# Word 기존: 742
# Word 주위: 741
# Word 행복: 740
# Word 사고력: 738
# Word 무지: 737
# Word 선경: 737
# Word 아버지: 735
# Word 영화: 735
# Word 센터: 735
# Word 실제: 735
# Word 첫째: 734
# Word 구멍: 734
# Word 사탐: 731
# Word 이란: 729
# Word 단대부고: 727
# Word 리하: 726
# Word 부동산: 725
# Word 수행: 724
# Word 편입: 724
# Word 풀이: 723
# Word 구매: 721
# Word 간단: 720
# Word 가나: 720
# Word 시스템: 720
# Word 돌파: 719
# Word 시댁: 719
# Word 여유: 717
# Word 지면: 715
# Word 시더: 714
# Word 중동고: 710
# Word 저런: 709
# Word 글로리아: 708
# Word 예상: 707
# Word 아인: 707
# Word 탐구: 705
# Word 아마: 703
# Word 평이: 703
# Word 휘문: 700
# Word 기회: 699
# Word ebs: 699
# Word 정해: 699
# Word 쓰시: 699
# Word 후회: 698
# Word 구나: 698
# Word 어차피: 696
# Word 바닥: 694
# Word 역삼: 694
# Word 영유: 694
# Word 화장실: 693
# Word 내면: 693
# Word 확통: 691
# Word 휴가: 691
# Word 데이: 690
# Word 사정: 690
# Word 고사: 690
# Word 라오: 689
# Word 피곤: 688
# Word 지문: 686
# Word 경제: 686
# Word 체력: 685
# Word 피아이: 685
# Word 금액: 682
# Word 오지: 681
# Word 구합: 681
# Word 일요일: 679
# Word 미술: 677
# Word 난리: 677
# Word 나머지: 677
# Word 러셀: 677
# Word 순간: 674
# Word 었는데: 674
# Word 외대: 670
# Word 여요: 669
# Word 특목고: 669
# Word 잠실: 669
# Word 학과: 667
# Word 유형: 667
# Word 4등급: 666
# Word 지지: 666
# Word 식당: 665
# Word 사이트: 665
# Word 요하: 665
# Word 잠시: 664
# Word 보지: 664
# Word 좀더: 664
# Word 날씨: 663
# Word 토요일: 663
# Word 종합: 663
# Word 만요: 661
# Word 라인: 659
# Word 집안: 658
# Word 운전: 657
# Word 최저: 656
# Word 이기: 656
# Word 교수: 655
# Word 기숙사: 653
# Word 만약: 651
# Word 이대: 650
# Word 학종: 650
# Word 가시: 648
# Word 답답: 644
# Word 정적: 643
# Word 위치: 643
# Word 대신: 638
# Word 정상: 637
# Word 김영준: 636
# Word 차라리: 635
# Word 가라: 635
# Word 입장: 634
# Word 리지: 633
# Word 중고: 633
# Word 인적: 633
# Word 이전: 630
# Word 인사: 630
# Word 다양: 629
# Word 몇개: 629
# Word 진단: 628
# Word 건강검진: 627
# Word 여러가지: 626
# Word 노래: 625
# Word 과제: 622
# Word 대찬: 622
# Word 자가: 621
# Word 안경: 621
# Word 회원: 620
# Word 침대: 620
# Word 유튜브: 619
# Word 인문: 619
# Word 파서: 619
# Word 방학동: 618
# Word 전사: 618
# Word 종류: 617
# Word 물화: 616
# Word 신고: 616
# Word 다음주: 616
# Word 린다: 616
# Word 인테리어: 616
# Word 일본: 613
# Word 어깨: 612
# Word 비문: 612
# Word 취업: 610
# Word 리기: 610
# Word 유치원: 609
# Word 신입생: 608
# Word 판단: 608
# Word 사시: 608
# Word 국어학: 608
# Word 여중: 607
# Word 수학과: 606
# Word 위로: 606
# Word 대회: 605
# Word 끼리: 605
# Word 가정: 604
# Word 현대: 604
# Word 부고: 603
# Word 달리: 602
# Word 예비중3: 602
# Word 렌즈: 601
# Word 명품: 601
# Word 서술: 601
# Word 정원: 600
# Word 고가: 600
# Word 도대체: 599
# Word 족하: 598
# Word 출신: 598
# Word 당장: 597
# Word 제외: 596
# Word 답글: 594
# Word 해빛: 592
# Word 선발: 592
# Word 반적: 592
# Word 계열: 591
# Word 화생: 591
# Word 우연: 590
# Word 가능성: 589
# Word 리뷰: 589
# Word 이틀: 588
# Word 출제: 587
# Word 지학: 586
# Word 무료: 585
# Word 성장: 585
# Word 사이즈: 584
# Word 일품: 584
# Word 인기: 583
# Word 남고: 583
# Word 교사: 582
# Word 선호: 582
# Word 거주: 580
# Word 습관: 580
# Word 정형외과: 578
# Word 인터뷰: 578
# Word 카톡: 575
# Word 등수: 574
# Word 이안: 573
# Word 주부: 572
# Word 약대: 572
# Word 곳도: 572
# Word 시술: 571
# Word 성공: 570
# Word 평범: 570
# Word 사거리: 570
# Word 체크: 569
# Word 오랜만: 568
# Word 과연: 566
# Word 교복: 564
# Word 계산: 563
# Word 어간: 562
# Word 방문: 562
# Word 니시: 562
# Word 장소: 562
# Word 수다: 560
# Word 의지: 560
# Word 생일: 560
# Word 그닥: 558
# Word 롯데: 558
# Word 자소: 558
# Word 현실: 557
# Word 파악: 555
# Word 대학병원: 553
# Word 로만: 553
# Word 파트: 552
# Word 자연: 552
# Word 모시: 552
# Word 단지: 552
# Word 통합: 551
# Word 안과: 550
# Word 물건: 550
# Word 대략: 549
# Word 충격: 549
# Word 라이: 548
# Word 막막: 548
# Word 지난주: 547
# Word 스피킹: 547
# Word 감기: 547
# Word 강아지: 546
# Word 미안: 545
# Word 음악: 545
# Word 시절: 545
# Word 한의원: 544
# Word 유리: 541
# Word 이정: 540
# Word 오픈: 539
# Word 대화: 539
# Word 고전: 537
# Word 실적: 537
# Word 보라: 536
# Word 변화: 534
# Word 화가: 534
# Word 주문: 533
# Word 사항: 533
# Word 결제: 533
# Word 우울증: 533
# Word 오신: 533
# Word 검진: 532
# Word 내시경: 531
# Word 갱년기: 531
# Word 계세: 530
# Word 분도: 529
# Word 피아노: 528
# Word 김선화: 527
# Word 초등때: 527
# Word 충분: 527
# Word sk: 526
# Word 직업: 526
# Word 두각: 525
# Word 스카이: 525
# Word 단대: 525
# Word 압구정: 524
# Word 거실: 523
# Word 나은: 523
# Word 굳이: 523
# Word 속도: 522
# Word 직원: 521
# Word 고기: 520
# Word 책상: 520
# Word 초보: 520
# Word 도저히: 519
# Word 교체: 517
# Word 스케줄: 517
# Word 전업: 516
# Word 미래: 516
# Word 한참: 515
# Word 버스: 515
# Word 나치: 514
# Word 세정: 514
# Word 필수: 511
# Word 내과: 511
# Word 에이: 511
# Word 듯이: 511
# Word 일부: 511
# Word 개학: 510
# Word 동아리: 510
# Word 중하: 506
# Word 월말: 505
# Word 역사: 505
# Word 기숙: 505
# Word 캠프: 504
# Word 마스크: 503
# Word 매장: 503
# Word 부러: 503
# Word 가까이: 503
# Word 당하: 502
# Word 학군: 502
# Word 분명: 500
# Word 마구: 500
# Word 기부: 500
# Word 영양: 499
# Word 오라: 499
# Word 동영상: 498
# Word 제풀이: 497
# Word 영상: 496
# Word 아줌마: 496
# Word 녀석: 495
# Word 과학학: 495
# Word 서류: 495
# Word 냉장고: 495
# Word 오니: 494
# Word 자랑: 493
# Word 사교육: 493
# Word 애매: 492
# Word 송파: 491
# Word 시리우스: 491
# Word 비율: 490
# Word 미용실: 490
# Word 내기: 490
# Word 작성: 490
# Word 시점: 489
# Word 저학년: 488
# Word 자신감: 487
# Word 시어머니: 486
# Word 배달: 486
# Word 심지어: 486
# Word 대하: 486
# Word 보아: 486
# Word 여주: 485
# Word 건물: 485
# Word 무시: 484
# Word 처리: 484
# Word 외과: 483
# Word 오시: 483
# Word 비타민: 483
# Word 오기: 482
# Word 가을: 482
# Word 기만: 482
# Word 덕스: 481
# Word 투자: 481
# Word 길이: 481
# Word 귀국: 481
# Word 쓰기: 480
# Word 지라: 480
# Word 자마자: 480
# Word 이혼: 479
# Word 드디어: 479
# Word 응용: 478
# Word 여지: 478
# Word 광고: 478
# Word 반찬: 477
# Word 영향: 477
# Word 번호: 477
# Word 대학교: 477
# Word 기적: 476
# Word 등교: 475
# Word 활용: 475
# Word 국내: 475
# Word 현역: 474
# Word 컴퓨터: 473
# Word 중학: 472
# Word 정신과: 472
# Word 공사: 472
# Word 상위: 472
# Word 향상: 470
# Word 마전: 470
# Word 현금: 469
# Word 중산고: 469
# Word 시원: 468
# Word 다이어트: 466
# Word 평생: 466
# Word 설치: 465
# Word 찾기: 464
# Word 전하: 464
# Word 지난번: 463
# Word 스터디: 462
# Word 숙명여고: 462
# Word 할인: 462
# Word 다운: 461
# Word 동시: 461
# Word 운영: 461
# Word 해당: 460
# Word 성형: 460
# Word 토론: 460
# Word 채점: 460
# Word 대치역: 460
# Word 드네: 460
# Word 진학사: 460
# Word 환경: 460
# Word 여러분: 459
# Word 해법: 459
# Word 추석: 459
# Word 이상하: 459
# Word 디자인: 459
# Word 예민: 458
# Word 블루스카이: 457
# Word 안타: 457
# Word 모양: 456
# Word 용돈: 456
# Word 일이: 455
# Word 주제: 454
# Word 부작용: 453
# Word 여전: 453
# Word 전과: 453
# Word 쇼핑: 452
# Word 지기: 452
# Word 우기: 451
# Word 윈터: 450
# Word ss: 450
# Word 저번: 450
# Word 강남구: 449
# Word 경쟁: 448
# Word 중대부고: 448
# Word 약속: 448
# Word 무릎: 448
# Word 소식: 447
# Word 네이버: 447
# Word 복용: 447
# Word 전국: 446
# Word 진심: 446
# Word 통화: 445
# Word 고견: 445
# Word 유럽: 445
# Word 드니: 444
# Word 날짜: 444
# Word 거지: 444
# Word 당일: 443
# Word 우리나라: 443
# Word 장점: 441
# Word 볼때: 441
# Word 도하: 441
# Word 탑반: 439
# Word 년도: 439
# Word 또한: 439
# Word 비중: 439
# Word 교육청: 438
# Word 세화여고: 438
# Word 반수: 438
# Word 상해: 437
# Word 멀리: 436
# Word 부산: 436
# Word 보톡스: 435
# Word 명의: 435
# Word 반대: 434
# Word 입하: 433
# Word 소화: 433
# Word 손용문: 432
# Word 오빠: 432
# Word 지혜: 431
# Word 생물: 431
# Word 군대: 431
# Word 주식: 430
# Word 가구: 428
# Word 흥미: 428
# Word 는가: 428
# Word 하진: 427
# Word 예비중2: 427
# Word 덧글: 427
# Word 수록: 426
# Word 입결: 426
# Word 삭제: 426
# Word 취소: 426
# Word 사라: 426
# Word 라며: 425
# Word 강좌: 424
# Word 개설: 424
# Word 교실: 424
# Word 제거: 424
# Word 그룹: 423
# Word 목걸이: 423
# Word 언급: 423
# Word 결석: 423
# Word 재종: 422
# Word 발견: 422
# Word 내지: 422
# Word 요청: 421
# Word 출근: 421
# Word 그릇: 421
# Word 액끼스: 420
# Word 코치: 420
# Word 라이드: 420
# Word 환불: 419
# Word 그거: 419
# Word 신문: 419
# Word 목소리: 419
# Word 행동: 418
# Word 대출: 418
# Word 용기: 418
# Word 연휴: 417
# Word 제발: 417
# Word 의자: 417
# Word 먹기: 417
# Word 잔소리: 416
# Word 실망: 416
# Word 연애: 415
# Word 중동: 415
# Word 실만: 415
# Word 정답: 415
# Word 해달: 415
# Word 금방: 414
# Word 스쿨: 414
# Word 전략: 413
# Word 주요: 412
# Word 상처: 411
# Word 현명: 411
# Word 참석: 411
# Word 당시: 410
# Word 반영: 410
# Word 가득: 410
# Word 퇴근: 410
# Word 프린트: 409
# Word 일도: 409
# Word 외모: 407
# Word 한마디: 407
# Word 계약: 406
# Word 다그: 406
# Word 물이: 406
# Word 움직: 406
# Word 화장: 405
# Word 제하: 405
# Word 두번째: 405
# Word 기운: 404
# Word 사건: 404
# Word 뉴스: 404
# Word 어른: 404
# Word 대명: 403
# Word 요리: 403
# Word 도서관: 403
# Word 자라: 403
# Word 담당: 403
# Word 불어: 402
# Word 어마: 402
# Word 수입: 401
# Word 내주: 401
# Word 성인: 401
# Word 제도: 401
# Word 나라: 400
# Word 요일: 400
# Word 입학사정관: 399
# Word 패스: 399
# Word 도전: 399
# Word 염색: 398
# Word sp: 398
# Word 변경: 397
# Word 이내: 396
# Word 고장: 396
# Word mi: 395
# Word 통계: 395
# Word 누적: 395
# Word 니나: 395
# Word 리스닝: 394
# Word 숙소: 394
# Word 하위: 393
# Word 친절: 393
# Word 사면: 393
# Word 현행: 393
# Word 완벽: 392
# Word 다방: 392
# Word 대학가: 392
# Word 원인: 392
# Word 한자: 391
# Word 경영: 391
# Word 하이: 391
# Word 세특: 391
# Word 대체: 390
# Word 옛날: 390
# Word 한편: 389
# Word 여야: 388
# Word 니니: 387
# Word 한쪽: 387
# Word 애도: 387
# Word 간식: 386
# Word 분야: 386
# Word 된거: 386
# Word 입원: 385
# Word 고급: 385
# Word 강대: 385
# Word 바지: 385
# Word 공감: 385
# Word 금요일: 385
# Word 은반: 383
# Word 시라: 383
# Word 눈치: 383
# Word 자궁: 383
# Word 고집: 383
# Word 긴장: 383
# Word 티비: 383
# Word 자유: 383
# Word 파인만: 382
# Word 글쓰기: 382
# Word 평일: 382
# Word 샤워: 382
# Word 주기: 381
# Word 피해: 381
# Word 월요일: 381
# Word 왼쪽: 380
# Word 더욱: 380
# Word 레슨: 380
# Word 주름: 379
# Word 이자: 379
# Word 문득: 379
# Word 수치: 379
# Word 코스: 378
# Word 대현: 378
# Word 헤어: 378
# Word 단순: 378
# Word 완성: 378
# Word 주일: 378
# Word 형편: 378
# Word 초음파: 377
# Word 아버님: 377
# Word 홈페이지: 376
# Word 회로: 375
# Word 각각: 375
# Word 통사: 374
# Word 연합: 374
# Word 킬러: 374
# Word 지구과학: 374
# Word 제출: 373
# Word 게시판: 373
# Word 대가: 372
# Word 요한: 372
# Word 원리: 371
# Word 라보: 371
# Word 최종: 371
# Word 블랙: 371
# Word 인정: 371
# Word 드림: 371
# Word 세화고: 371
# Word 방송: 370
# Word 종종: 370
# Word 과학고: 370
# Word 로서: 370
# Word 공개: 370
# Word 연고: 369
# Word 엉망: 369
# Word 제주도: 369
# Word 차로: 369
# Word 무척: 369
# Word 한시: 368
# Word 반지: 368
# Word 초딩: 368
# Word 만만: 367
# Word 경쟁률: 367
# Word 커서: 367
# Word 들보: 366
# Word 수정: 366
# Word 도시락: 366
# Word 할머니: 365
# Word 경력: 365
# Word 자율고: 364
# Word 급식: 364
# Word 세계: 364
# Word 주지: 363
# Word 일인: 363
# Word 지식: 363
# Word 서인: 363
# Word 주의: 363
# Word 민사고: 363
# Word 안정: 362
# Word 공간: 362
# Word 나기: 362
# Word 당황: 361
# Word 5등급: 360
# Word 그림: 360
# Word 요지: 360
# Word 개포: 360
# Word 엉덩이: 360
# Word 실패: 360
# Word 무난: 359
# Word 치아: 359
# Word 빨래: 358
# Word 외식: 358
# Word 칭찬: 358
# Word 커버: 357
# Word 중국어: 357
# Word 수영: 357
# Word 이마: 356
# Word 목적: 356
# Word 케이스: 356
# Word 천하: 355
# Word 연산: 354
# Word 감정: 354
# Word 불리: 354
# Word 상상: 354
# Word 기록: 353
# Word 방금: 353
# Word 객관: 352
# Word 순서: 352
# Word 연결: 351
# Word 나타: 351
# Word 게다가: 351
# Word 르네: 350
# Word 인근: 350
# Word 반도: 350
# Word 산부인과: 350
# Word 합격자: 350
# Word 서부: 349
# Word 오른쪽: 349
# Word 식구: 349
# Word 민하: 349
# Word 사립: 348
# Word 중위: 348
# Word 기침: 348
# Word 조건: 348
# Word 각자: 347
# Word 시구: 346
# Word 종이: 345
# Word 덕분: 345
# Word 메뉴: 345
# Word 시계: 345
# Word 두통: 345
# Word 치열: 344
# Word 이루: 344
# Word 시장: 344
# Word 확률: 344
# Word 스토리: 344
# Word 막내: 344
# Word 시가: 343
# Word 생명과학: 343
# Word 성대: 343
# Word 수면: 343
# Word 우수: 343
# Word a1: 342
# Word 세금: 342
# Word 여성: 341
# Word 갈수록: 341
# Word 취미: 341
# Word 저리: 341
# Word 대청중: 341
# Word 하늘: 341
# Word 일로: 341
# Word 정예: 341
# Word 슬슬: 341
# Word 심장: 340
# Word 화장품: 340
# Word 선생: 340
# Word 샤론: 340
# Word 전이: 340
# Word 가성: 339
# Word 고수: 339
# Word 주어: 339
# Word 은행: 339
# Word 년전: 339
# Word 도입: 338
# Word 이학원: 338
# Word 빡세: 337
# Word 구분: 337
# Word 기능: 337
# Word 렉슬: 336
# Word 세탁기: 336
# Word 방이: 336
# Word 망설: 335
# Word 위험: 335
# Word 집도: 335
# Word 세브란스: 334
# Word 축하: 334
# Word 명절: 333
# Word 아내: 333
# Word 심란: 332
# Word 스마트폰: 332
# Word 상당: 332
# Word 학점: 332
# Word 대학입시: 332
# Word 이비인후과: 332
# Word 적성: 331
# Word 모자: 331
# Word 불가능: 331
# Word 간절: 330
# Word 대장: 330
# Word 시중: 330
# Word 소설: 330
# Word 김치: 330
# Word 비슷: 329
# Word 윈터스: 329
# Word 신발: 329
# Word 한약: 329
# Word 분당: 328
# Word 봉사: 327
# Word 대원외고: 327
# Word 플라즈마: 327
# Word 기타: 326
# Word am: 326
# Word 로스쿨: 326
# Word 스카: 326
# Word 방특: 325
# Word 서비스: 325
# Word 모델: 325
# Word 연수: 324
# Word 개정: 323
# Word 었습니: 323
# Word 노트: 323
# Word 식탁: 323
# Word 일대일: 322
# Word 그날: 322
# Word 노후: 322
# Word 의심: 321
# Word 도착: 321
# Word 주차장: 321
# Word 기미: 321
# Word 소문: 321
# Word 영재원: 320
# Word 크림: 320
# Word 올림피아드: 320
# Word 대적: 320
# Word 장하: 320
# Word 필립: 319
# Word 절실: 318
# Word 건조기: 318
# Word 건조: 318
# Word 시력: 318
# Word 하나고: 318
# Word 제주: 317
# Word 약국: 317
# Word 레이저: 317
# Word 현대고: 317
# Word 에어: 317
# Word 피하: 316
# Word 의치: 316
# Word 신랑: 316
# Word 생활비: 315
# Word 대답: 315
# Word 리터니: 314
# Word 의욕: 314
# Word 전기: 313
# Word 사과: 313
# Word 비염: 312
# Word 진정: 312
# Word 대면: 312
# Word 크기: 311
# Word 자하: 311
# Word 행사: 311
# Word 천개: 311
# Word 캐나다: 311
# Word 전문가: 310
# Word 유투브: 310
# Word 갈등: 310
# Word 마찬가지: 310
# Word 매하: 310
# Word 나인: 310
# Word 단기: 310
# Word 한숨: 309
# Word 구성: 309
# Word 공통: 309
# Word 근무: 308
# Word msc: 308
# Word 단위: 308
# Word 코트: 308
# Word 보충: 307
# Word 등부: 307
# Word 경기도: 307
# Word 체육: 307
# Word 극적: 307
# Word 인하: 307
# Word 태도: 307
# Word 마사지: 306
# Word 부과: 306
# Word 연예인: 306
# Word 와중: 306
# Word 소형: 306
# Word 소득: 306
# Word 초등학생: 305
# Word 래미: 305
# Word 교회: 305
# Word 낭비: 305
# Word 인증: 305
# Word 요약: 305
# Word 시지: 305
# Word 시부: 304
# Word 참여: 304
# Word 주심: 304
# Word 다라: 303
# Word 실정: 303
# Word 플러스: 302
# Word 그간: 302
# Word 제적: 302
# Word 효율: 301
# Word 보이지: 301
# Word 발목: 301
# Word 연세대: 301
# Word 시반: 301
# Word 시설: 301
# Word 소파: 301
# Word 기기: 301
# Word 주중: 300
# Word 구경: 300
# Word 다이아: 300
# Word 체계: 299
# Word 연기: 299
# Word 문항: 299
# Word 백봉용: 299
# Word 반응: 299
# Word 타임: 298
# Word 전날: 297
# Word 커리큘럼: 297
# Word 조차: 297
# Word 세입: 296
# Word 어이: 296
# Word 학업: 296
# Word 환자: 296
# Word 고합: 296
# Word 재학: 296
# Word 한글: 296
# Word 듭니: 296
# Word 치면: 296
# Word 대표: 295
# Word 공학: 295
# Word 제시: 295
# Word 차려: 295
# Word 지하철: 295
# Word 절하: 294
# Word 체험: 294
# Word 조절: 294
# Word 방과후: 293
# Word 나가야: 293
# Word 자격증: 293
# Word 귀가: 293
# Word 한적: 293
# Word 직전: 293
# Word 지게: 293
# Word 붙이: 292
# Word 깊이: 292
# Word 패키지: 291
# Word 려구: 291
# Word 월초: 291
# Word 차량: 291
# Word 이불: 291
# Word 최대한: 291
# Word 영독: 291
# Word 과일: 291
# Word 응급실: 290
# Word 문화: 290
# Word 다수: 290
# Word 주방: 290
# Word 고원: 290
# Word 경희대: 289
# Word 재산: 288
# Word 여부: 288
# Word 불구: 288
# Word 초고: 288
# Word 시즌: 288
# Word 달래: 287
# Word 만기: 287
# Word 블스: 287
# Word 유방: 287
# Word 가오: 287
# Word 만해: 286
# Word 점검: 286
# Word 손가락: 286
# Word 연세: 285
# Word 영문법: 285
# Word 축구: 285
# Word 자아: 285
# Word 반드시: 285
# Word 반고: 284
# Word 식이: 284
# Word 유행: 284
# Word 도로: 284
# Word 한양대: 283
# Word 재시: 283
# Word 공인: 283
# Word 외부: 283
# Word 적합: 282
# Word 세번: 282
# Word 필라테스: 282
# Word 달이: 282
# Word 제목: 282
# Word 요가: 282
# Word 형제: 282
# Word 데스크: 281
# Word 적용: 281
# Word 응시: 281
# Word 휘문중: 281
# Word 유독: 280
# Word 남친: 280
# Word 새움: 280
# Word 대서: 280
# Word 일지: 279
# Word 영하: 279
# Word 며느리: 279
# Word 수행평가: 279
# Word 사업: 279
# Word 기력: 279
# Word 팔찌: 279
# Word 성취도: 279
# Word 의료: 278
# Word 아저씨: 278
# Word 재원: 278
# Word 중앙: 278
# Word 오십: 278
# Word 인상: 278
# Word 의문: 278
# Word 물올: 277
# Word 외출: 277
# Word 일전: 277
# Word 거래: 277
# Word 차도: 277
# Word 홈피: 277
# Word 올인: 277
# Word 해석: 276
# Word 살림: 276
# Word 강북: 276
# Word 여행가: 276
# Word 익명: 275
# Word 엠솔: 275
# Word 디스크: 275
# Word 기정: 275
# Word 심각: 275
# Word 한잔: 274
# Word 걷기: 274
# Word 학번: 274
# Word 제공: 273
# Word 소용: 273
# Word 산책: 273
# Word 셔틀: 273
# Word 누군가: 273
# Word 고다: 273
# Word 워킹맘: 273
# Word 난감: 272
# Word 결론: 272
# Word 간신: 272
# Word 부근: 272
# Word 고루: 272
# Word 통장: 272
# Word 실험: 272
# Word 계좌: 271
# Word 도우미: 271
# Word 청소기: 271
# Word 증여: 271
# Word 세탁: 271
# Word 요구: 271
# Word 건너: 270
# Word 편안: 270
# Word 낫다: 270
# Word 말리: 270
# Word 최소: 270
# Word 구해: 269
# Word 실전: 269
# Word 과도: 269
# Word 보관: 269
# Word 집주인: 268
# Word 각종: 268
# Word 꾸벅: 268
# Word 문장: 268
# Word 정작: 268
# Word 지속: 268
# Word 보더: 267
# Word 거울: 267
# Word 인간: 267
# Word 영어실력: 267
# Word 패딩: 267
# Word 사기: 266
# Word 시도: 266
# Word 두시: 266
# Word 메가스터디: 265
# Word 아이엘이: 265
# Word 링크: 265
# Word 월급: 265
# Word 근육: 265
# Word 창문: 264
# Word 연구: 264
# Word 익숙: 264
# Word 매달: 264
# Word 업무: 263
# Word 확정: 263
# Word 어쩜: 263
# Word 조사: 263
# Word 양쪽: 263
# Word 일수: 263
# Word 특징: 262
# Word 무식: 262
# Word 주소: 262
# Word 샘반: 262
# Word 전문직: 262
# Word 예체능: 262
# Word 전환: 262
# Word 욕실: 261
# Word 비행기: 261
# Word 영동고: 261
# Word 세대: 261
# Word 우려: 260
# Word 다해: 260
# Word 주간: 260
# Word 마트: 260
# Word 주하: 260
# Word 차례: 260
# Word 상의: 260
# Word 멘붕: 260
# Word 확진: 259
# Word 국가: 259
# Word 연하: 259
# Word ms: 258
# Word 인지도: 258
# Word 안전: 258
# Word 훈련: 258
# Word 임원: 257
# Word 다오: 257
# Word 시험지: 257
# Word 제량: 257
# Word 이상은: 257
# Word 구조: 257
# Word 회복: 256
# Word 수업료: 256
# Word 부엉이: 256
# Word 치매: 256
# Word 변호사: 256
# Word 에이펙스: 256
# Word 악기: 256
# Word 재능: 255
# Word 항생제: 255
# Word 당근: 255
# Word 원어민: 255
# Word 순위: 254
# Word 청소년: 254
# Word 전망: 254
# Word 간이: 254
# Word 스펙: 254
# Word 스케쥴: 254
# Word 인스타: 254
# Word 대고: 254
# Word 유난: 254
# Word 눈썹: 254
# Word 아직까지: 254
# Word 은근: 254
# Word 대기업: 254
# Word 글씨: 253
# Word 나무: 253
# Word 자전거: 253
# Word 작품: 253
# Word 최초: 253
# Word 종로: 253
# Word 휴학: 253
# Word 운동화: 252
# Word 잠도: 252
# Word 적도: 252
# Word 예습: 252
# Word 반입: 252
# Word 1%: 252
# Word 케어: 251
# Word 관해: 251
# Word 감각: 251
# Word 문하: 251
# Word 베란다: 250
# Word 차근차근: 250
# Word 한문: 250
# Word 소장: 250
# Word 중국: 249
# Word 노트북: 249
# Word 코스트코: 249
# Word 첫날: 248
# Word 입반: 248
# Word 상한: 248
# Word 혼란: 248
# Word 소하: 248
# Word 신축: 248
# Word 샴푸: 248
# Word 폐경: 248
# Word 대학원: 248
# Word 자동차: 248
# Word 실내: 247
# Word 하소연: 247
# Word 황당: 247
# Word 서울시: 247
# Word 양재천: 247
# Word 학교생활: 247
# Word 입맛: 247
# Word 과중: 247
# Word 일상: 247
# Word 예비초6: 246
# Word 주인: 246
# Word 서서: 246
# Word 실장: 246
# Word 이은직: 246
# Word 장애: 246
# Word 규모: 246
# Word 고려대: 245
# Word 독학: 245
# Word 미친: 245
# Word 윤도영: 245
# Word 깜짝: 245
# Word 공지: 245
# Word 자퇴: 245
# Word 컨디션: 244
# Word 문이과: 244
# Word 기면: 244
# Word 학력: 244
# Word 아타: 244
# Word 이수: 244
# Word 기계: 244
# Word 대인: 243
# Word 거부: 243
# Word 한학: 243
# Word 고이: 243
# Word 실지: 243
# Word 월세: 243
# Word 맞벌이: 242
# Word 베이트: 242
# Word 사람인: 242
# Word 에디센: 242
# Word 가운데: 242
# Word 용해: 242
# Word 서초구: 242
# Word 이분: 242
# Word 극복: 242
# Word 형식: 242
# Word 본격: 242
# Word 경향: 241
# Word 신어지: 241
# Word 출발: 241
# Word 교권: 241
# Word 부위: 240
# Word 동일: 240
# Word 홍보: 240
# Word 단점: 240
# Word 농구: 240
# Word 어려움: 240
# Word 마리: 239
# Word 홈쇼핑: 239
# Word 소마: 239
# Word 파이널: 239
# Word 세트: 239
# Word 어쩌: 239
# Word 매년: 239
# Word 정이: 238
# Word 제한: 238
# Word 상품: 238
# Word 일어나서: 238
# Word 개원: 238
# Word 막연: 237
# Word 중순: 237
# Word 안방: 237
# Word 고아: 237
# Word 고마: 237
# Word 여태: 236
# Word 장난: 236
# Word 몰래: 236
# Word 대도: 236
# Word 중단: 235
# Word 한계: 235
# Word 주전: 235
# Word 판서: 235
# Word 사례: 235
# Word 견적: 235
# Word 요요: 235
# Word 리나: 235
# Word 밤새: 235
# Word 간담: 234
# Word 휴대폰: 234
# Word 개포고: 234
# Word 생신: 234
# Word 특정: 234
# Word 양재고: 234
# Word 타운: 234
# Word 십년: 234
# Word 은애: 234
# Word 몇몇: 234
# Word 제로: 233
# Word 자연계: 233
# Word 나은지: 233
# Word 장단점: 233
# Word 래미안: 233
# Word 리다: 233
# Word 리더: 233
# Word 수요일: 233
# Word 특기자: 232
# Word 명인: 232
# Word 명정: 232
# Word 어학: 232
# Word 비도: 232
# Word 갈리: 232
# Word 입력: 231
# Word 까페: 231
# Word 학부: 231
# Word 만난: 231
# Word 소심: 231
# Word 귀걸이: 231
# Word 불만: 230
# Word 이모: 230
# Word 학급: 230
# Word 브릿지: 230
# Word 멘탈: 230
# Word 연금: 229
# Word 중대: 229
# Word 심리: 229
# Word 에듀: 229
# Word 보고서: 228
# Word 대수: 228
# Word 자율: 228
# Word 통학: 228
# Word 교내: 228
# Word 철저: 228
# Word 동하: 228
# Word 일본어: 228
# Word 타이: 227
# Word 사설: 227
# Word 한동: 227
# Word 냉동: 227
# Word 조합: 227
# Word 정부: 227
# Word 사가: 227
# Word 미대: 227
# Word 거구: 226
# Word 퇴직: 226
# Word 기술: 226
# Word 쿠팡: 226
# Word 고통: 226
# Word 접근: 226
# Word 몸무게: 226
# Word 포인트: 226
# Word 내세: 225
# Word peai: 225
# Word 오른: 225
# Word 뿌리: 225
# Word 해먹: 225
# Word 진행중: 224
# Word 후배: 224
# Word 이제야: 224
# Word 용한: 224
# Word 천만원: 223
# Word 은광: 223
# Word 억지로: 223
# Word 강배: 223
# Word 심정: 223
# Word 아름: 223
# Word 버거: 223
# Word 산다: 223
# Word 배송: 222
# Word 특목: 222
# Word 센스: 221
# Word 이외: 221
# Word 정책: 220
# Word 신뢰: 220
# Word 아카데미: 220
# Word 들것: 220
# Word 타입: 220
# Word 우시: 220
# Word 평가원: 220
# Word 보나: 220
# Word 집앞: 220
# Word 메가: 220
# Word 강남역: 220
# Word 응원: 220
# Word 오랫동안: 220
# Word 논리: 220
# Word 택배: 219
# Word 알러지: 219
# Word 선정: 219
# Word 명문: 219
# Word 백신: 219
# Word 맥주: 219
# Word 재학생: 219
# Word 차원: 218
# Word 한가지: 218
# Word 국민: 218
# Word 주관: 218
# Word 하루하루: 217
# Word 나오니: 217
# Word 화목: 217
# Word 살기: 217
# Word 세월: 217
# Word 회장: 217
# Word 아라: 217
# Word 애기: 216
# Word 더러: 216
# Word 실비: 216
# Word 조교: 216
# Word 라식: 216
# Word 다소: 216
# Word 이세: 216
# Word 설득: 216
# Word 거짓말: 216
# Word 강기원: 216
# Word 재건축: 215
# Word 형태: 215
# Word 에나: 215
# Word 권유: 215
# Word 친척: 215
# Word 강제: 215
# Word 예측: 215
# Word 똑똑: 215
# Word 입문: 214
# Word 전쟁: 214
# Word 뉴욕: 214
# Word 수선: 214
# Word 회도: 214
# Word 예금: 214
# Word 동기: 214
# Word 바보: 214
# Word 교육과정: 214
# Word 학감: 213
# Word 막강: 213
# Word 앞서: 213
# Word 택시: 213
# Word 반짝: 213
# Word 시리즈: 213
# Word 상향: 213
# Word 생으로: 212
# Word 시골: 212
# Word 프리미엄: 212
# Word 미니: 212
# Word 출판사: 212
# Word 게시: 212
# Word 회의: 212
# Word 바다: 212
# Word 고치: 211
# Word 특성: 211
# Word 예고: 211
# Word 나이스: 211
# Word 주택: 211
# Word 강민철: 211
# Word 라벨: 211
# Word 소변: 211
# Word 지각: 211
# Word 출장: 211
# Word 초기: 210
# Word 배치: 210
# Word 교대: 210
# Word 마루: 210
# Word 별도: 210
# Word 현우진: 210
# Word 핑계: 210
# Word 치하: 210
# Word 님반: 209
# Word 작가: 209
# Word 메이저: 209
# Word 노하우: 209
# Word 바이올린: 209
# Word 대청: 209
# Word 수금: 209
# Word 탈모: 209
# Word 만족도: 208
# Word 인용: 208
# Word 싸움: 208
# Word 집안일: 208
# Word 지갑: 208
# Word 핵심: 208
# Word 천원: 208
# Word 해설: 208
# Word 기자: 207
# Word 좌절: 207
# Word 특이: 207
# Word 가죽: 207
# Word 중점: 206
# Word 도형: 206
# Word 허락: 206
# Word 의외: 206
# Word 강정화: 206
# Word 은광여고: 206
# Word 마스터: 206
# Word 작고: 206
# Word 그루샘: 206
# Word 지루: 206
# Word 이맥스: 206
# Word 남녀공학: 206
# Word 고속: 206
# Word 주민: 206
# Word 감동: 206
# Word 온갖: 205
# Word 전달: 205
# Word 연락처: 205
# Word 큰일: 205
# Word 실시: 205
# Word 아웃: 205
# Word 안쪽: 204
# Word 소위: 204
# Word 블라인드: 204
# Word 적절: 204
# Word 다기: 204
# Word 임플란트: 204
# Word 롸이팅: 203
# Word 블로그: 203
# Word 맞춤: 203
# Word 루고: 203
# Word 바퀴: 203
# Word 자격: 203
# Word 보장: 203
# Word 염두: 202
# Word 대박: 202
# Word 강조: 202
# Word 센티: 202
# Word 영수: 202
# Word 서강대: 202
# Word 높이: 202
# Word 과거: 202
# Word 엄두: 202
# Word 핸폰: 202
# Word 마침: 202
# Word 염증: 202
# Word 따라서: 201
# Word 숫자: 201
# Word 소재: 201
# Word 컴공: 201
# Word 추억: 201
# Word 격리: 201
# Word 전자: 201
# Word 박동우: 201
# Word 저하: 201
# Word 필기: 200
# Word 대딩: 200
# Word snt: 200
# Word 도곡동: 200
# Word 포장: 200
# Word 표정: 200
# Word 차고: 200
# Word 해외여행: 200
# Word 누나: 200
# Word 현장: 199
# Word 생인: 199
# Word 김동욱: 199
# Word 보강: 199
# Word 출하: 199
# Word 당신: 199
# Word 외국인: 199
# Word 임동호: 199
# Word 넷플릭스: 199
# Word 수강신청: 198
# Word 별거: 198
# Word 일보: 198
# Word 로션: 198
# Word 정성: 198
# Word 잔뜩: 198
# Word 공기: 197
# Word 스탈: 197
# Word 카이스트: 197
# Word 번은: 197
# Word 단체: 197
# Word 체중: 197
# Word 안남: 197
# Word 조기: 197
# Word 전해: 197
# Word 김정준: 196
# Word 간만: 196
# Word 대통령: 196
# Word 자취: 196
# Word 퇴원: 196
# Word 탄탄: 196
# Word 책임: 196
# Word 피드백: 196
# Word 실기: 196
# Word 선제: 195
# Word 오래전: 195
# Word 답지: 195
# Word 발라: 195
# Word 프라임: 195
# Word 온몸: 195
# Word 엑스레이: 195
# Word 억울: 195
# Word 안보라: 195
# Word 단평: 195
# Word 머리카락: 194
# Word 반면: 194
# Word 현상: 194
# Word 요강: 194
# Word 러시: 194
# Word 지리: 193
# Word 경찰: 193
# Word 체육복: 193
# Word 만날: 193
# Word 시행: 193
# Word 그다지: 193
# Word 설마: 192
# Word 박사: 192
# Word 역량: 192
# Word 고오: 192
# Word 일부러: 191
# Word 영국: 191
# Word 더더: 191
# Word 지경: 191
# Word 이론: 191
# Word 대책: 190
# Word 제법: 190
# Word 예산: 190
# Word 아이디어: 190
# Word 중상: 190
# Word 서성: 190
# Word 자극: 190
# Word 쌍수: 190
# Word 소음: 190
# Word 대원: 190
# Word 처참: 190
# Word 리라: 189
# Word 요양: 189
# Word 동의: 189
# Word 담배: 189
# Word 혼공: 189
# Word 마저: 189
# Word 금융: 189
# Word 운지: 189
# Word 존재: 189
# Word 상이: 189
# Word 성과: 189
# Word 불합격: 189
# Word 유산균: 189
# Word 떡볶이: 188
# Word 빡센: 188
# Word 얘길: 188
# Word 결혼식: 188
# Word 배경: 188
# Word 셨는데: 188
# Word 연한: 187
# Word 근방: 187
# Word 지구: 187
# Word 프라우드7: 187
# Word 열정: 187
# Word 추어: 187
# Word 라지: 187
# Word 벌이: 187
# Word 정기: 187
# Word 전후: 187
# Word 벤츠: 187
# Word 직하: 186
# Word 열공: 186
# Word 수영장: 186
# Word 몰입: 186
# Word 관절: 186
# Word 하교: 186
# Word 진자: 186
# Word 득점: 185
# Word 확대: 185
# Word 발치: 185
# Word 삼수: 185
# Word 야합: 185
# Word 증세: 185
# Word 금지: 185
# Word 결심: 185
# Word 당한: 185
# Word 용인: 185
# Word 지금껏: 185
# Word 아토피: 185
# Word 콘서트: 185
# Word 최현호: 185
# Word 사전: 185
# Word 세기: 184
# Word 공연: 184
# Word 어법: 184
# Word 매트리스: 184
# Word 인성: 184
# Word 먼지: 184
# Word 블루: 184
# Word 살수: 184
# Word 대부: 184
# Word 성하: 184
# Word 석차: 184
# Word 부엌: 184
# Word 도통: 183
# Word 비만: 183
# Word 아이폰: 183
# Word 중력: 183
# Word 공동: 183
# Word 다다: 183
# Word 음식점: 183
# Word 에세이: 183
# Word 수능시험: 183
# Word 여대: 182
# Word 남동생: 182
# Word 충실: 182
# Word 표시: 182
# Word 시간대: 182
# Word 의원: 182
# Word 대구: 182
# Word 인도: 182
# Word 풍문: 182
# Word 도배: 182
# Word 자동: 182
# Word 이중: 182
# Word 어쩌면: 182
# Word 교육비: 181
# Word 졸업생: 181
# Word 양하: 181
# Word 누수: 181
# Word 요전: 181
# Word 눈밑: 181
# Word 판매: 181
# Word 의무: 181
# Word 에너지: 180
# Word 우유: 180
# Word 다주: 180
# Word 리저: 180
# Word 도수: 180
# Word 가량: 180
# Word 홍삼: 180
# Word bmi: 180
# Word 약도: 179
# Word 인덕션: 179
# Word 오류: 179
# Word 총회: 179
# Word 리가: 179
# Word 두루: 178
# Word 도서: 178
# Word 기지: 178
# Word 불가: 178
# Word 회화: 178
# Word 고서: 178
# Word 었다: 178
# Word 회하: 178
# Word 교시: 177
# Word 정치: 177
# Word 강릉: 177
# Word 또래: 177
# Word 박종민: 177
# Word 배려: 177
# Word 부어: 177
# Word 호르몬: 177
# Word 돌이: 176
# Word 부가: 176
# Word 아너스: 176
# Word 아기: 176
# Word 추첨: 176
# Word 여친: 176
# Word 전화번호: 176
# Word 조정: 176
# Word 손님: 176
# Word 조직검사: 176
# Word 마련: 176
# Word 절반: 175
# Word 무거: 175
# Word 연속: 175
# Word 역할: 175
# Word 가다가: 175
# Word 감독: 175
# Word 혈압: 175
# Word 상적: 175
# Word 노인: 175
# Word 화요일: 174
# Word 소견: 174
# Word 횟수: 174
# Word 세종: 174
# Word 다섯: 174
# Word 남녀: 174
# Word 강원도: 174
# Word 색깔: 173
# Word 스타: 173
# Word 나들이: 173
# Word 간지: 173
# Word 서점: 173
# Word 두피: 173
# Word 민망: 172
# Word 잇몸: 172
# Word 주정: 172
# Word 시아버지: 172
# Word 유료: 172
# Word 말투: 172
# Word 믿음: 172
# Word 순이: 172
# Word 발생: 172
# Word 목요일: 172
# Word 안계: 172
# Word 심심: 171
# Word 가치: 171
# Word 연말: 171
# Word 기파랑: 171
# Word 상대: 171
# Word 아이패드: 171
# Word 험담: 171
# Word 여보: 171
# Word 흰색: 170
# Word 검정: 170
# Word 러더: 170
# Word 저기: 170
# Word 박스: 170
# Word 입구: 170
# Word 밀리: 170
# Word 중독: 170
# Word 등록금: 170
# Word 요소: 170
# Word 자존감: 170
# Word 망치: 170
# Word 국사: 170
# Word 봉사활동: 170
# Word 아울렛: 170
# Word 마취: 169
# Word 쌤반: 169
# Word 고개: 169
# Word 대한민국: 169
# Word 마을: 169
# Word 유방암: 169
# Word 평상시: 169
# Word 모기: 169
# Word 부쩍: 169
# Word 시부모: 169
# Word 자제: 169
# Word 재료: 169
# Word 반포고: 168
# Word 일시: 168
# Word 이벤트: 168
# Word 독감: 168
# Word 기관: 168
# Word 여자애: 168
# Word 캠퍼스: 168
# Word 새해: 168
# Word 이감: 168
# Word 대성: 168
# Word 흐름: 167
# Word 코엑스: 167
# Word 참으로: 167
# Word 종반: 166
# Word 패드: 166
# Word 영어문법: 166
# Word 제사: 166
# Word 부인: 166
# Word 나야: 166
# Word 의식: 165
# Word 신세계: 165
# Word 설사: 165
# Word 휴강: 165
# Word 고양이: 165
# Word 고정: 165
# Word 기입: 164
# Word 어째: 164
# Word 상품권: 164
# Word 자사: 164
# Word 살때: 164
# Word 모자라: 164
# Word 차단: 164
# Word 공식: 164
# Word 즈음: 163
# Word 클릭: 163
# Word 장학금: 163
# Word 완료: 163
# Word 최소한: 163
# Word 혜택: 163
# Word 안주: 163
# Word 마냥: 163
# Word 놀이: 163
# Word 도곡역: 163
# Word 난하: 163
# Word 한창: 162
# Word 도무지: 162
# Word 이해력: 162
# Word 양도: 162
# Word 로부터: 162
# Word 전회경: 162
# Word 내외: 162
# Word 엘지: 162
# Word 대안: 162
# Word 확장: 162
# Word 사무실: 161
# Word 야채: 161
# Word 토대: 161
# Word 얼른: 161
# Word 역학: 161
# Word 점도: 161
# Word 최대: 161
# Word 년대: 161
# Word 갑상선: 161
# Word 구몬: 161
# Word 강력: 161
# Word 가신: 161
# Word 클래스: 161
# Word 튀어: 161
# Word 근거: 161
# Word 개포동: 160
# Word 부자: 160
# Word 어린이: 160
# Word 일자: 160
# Word 었던: 160
# Word 증후군: 160
# Word 창의: 160
# Word 금은: 160
# Word 수강생: 160
# Word 웨이: 160
# Word 학우: 159
# Word 세제: 159
# Word 할아버지: 159
# Word 이왕이면: 159
# Word 염려: 159
# Word 래야: 158
# Word 지점: 158
# Word 도성: 158
# Word 속옷: 158
# Word 벌레: 158
# Word 접종: 158
# Word 자유여행: 158
# Word 백분: 157
# Word 기재: 157
# Word 전적: 157
# Word 쌍꺼풀: 157
# Word 졸업식: 157
# Word 착용: 157
# Word 분한: 157
# Word 전문의: 157
# Word 냄비: 157
# Word 반정: 157
# Word 개선: 156
# Word 콜레스테롤: 156
# Word 픽업: 156
# Word 오해: 156
# Word 입학시험: 156
# Word 아가시: 156
# Word 종합병원: 156
# Word 참가: 156
# Word 매매: 156
# Word 지시: 156
# Word 도움말: 156
# Word 한해: 156
# Word 설거지: 155
# Word 커트라인: 155
# Word 성의: 155
# Word 과로: 155
# Word 감점: 155
# Word 대강: 155
# Word 주장: 155
# Word 출처: 155
# Word 시오: 155
# Word 외동: 154
# Word 부교: 154
# Word 목록: 154
# Word 절대평가: 154
# Word 지옥: 154
# Word 천장: 154
# Word 종아리: 154
# Word 상속: 154
# Word 양재: 154
# Word 약사: 154
# Word 버티고: 154
# Word 형님: 154
# Word 승급: 154
# Word 취직: 154
# Word 소통: 154
# Word 작업: 153
# Word 따님: 153
# Word 보호: 153
# Word 고지: 153
# Word 알리: 153
# Word 곰팡이: 153
# Word 채널: 153
# Word 화상: 153
# Word ges: 153
# Word 모범생: 153
# Word 도적: 153
# Word 확신: 153
# Word 장면: 153
# Word 차선: 153
# Word 브런치: 153
# Word 홍대: 153
# Word 요령: 153
# Word 교환학생: 153
# Word 간혹: 152
# Word 편지: 152
# Word 선릉: 152
# Word 공립: 152
# Word 강화: 152
# Word 박민수: 152
# Word 지적: 152
# Word 국수: 152
# Word 상승: 152
# Word 감당: 152
# Word 더위: 152
# Word 취하: 152
# Word 여동생: 152
# Word 화작: 151
# Word 비법: 151
# Word 상식: 151
# Word 원가: 151
# Word 평수: 151
# Word 스레: 151
# Word 원망: 151
# Word 상경: 151
# Word 노화: 151
# Word 훌쩍: 151
# Word 키도: 150
# Word 양해: 150
# Word 건대: 150
# Word 관계자: 150
# Word 달달: 150
# Word 글자: 150
# Word 충치: 150
# Word 이공: 150
# Word 보석: 149
# Word 싱크대: 149
# Word 듀얼: 149
# Word 이마트: 149
# Word 성당: 149
# Word 가수: 149
# Word 그래머: 149
# Word 코앞: 149
# Word 방안: 149
# Word 다나: 149
# Word 추적: 149
# Word 간의: 149
# Word 엊그제: 149
# Word 노안: 149
# Word 김승리: 149
# Word 아이파크: 149
# Word 지능: 149
# Word 계란: 149
# Word 안심: 148
# Word 보구: 148
# Word 당뇨: 148
# Word 기원: 148
# Word 박영석: 148
# Word 성균관대: 148
# Word 라야: 148
# Word 요정: 148
# Word 열흘: 148
# Word 세부: 148
# Word 입금: 148
# Word 한의대: 148
# Word 부정: 148
# Word 메인: 147
# Word 규칙: 147
# Word 주가: 147
# Word 글로벌: 147
# Word 과자: 147
# Word 장만: 147
# Word 대처: 147
# Word 하하: 147
# Word 종교: 147
# Word 바탕: 147
# Word 부장: 147
# Word 무하: 147
# Word 대학별: 146
# Word 원점: 146
# Word 답안: 146
# Word 고난: 146
# Word 독립: 146
# Word 대중교통: 146
# Word 남매: 146
# Word 이드: 146
# Word 기름: 146
# Word 야만: 146
# Word 발령: 146
# Word 다한: 146
# Word 허벅지: 146
# Word 대세: 145
# Word 골목: 145
# Word 쓰레기: 145
# Word 나나: 145
# Word 스킨: 145
# Word 리도: 145
# Word 커녕: 145
# Word 교하: 145
# Word 폭망: 145
# Word 력도: 145
# Word 이명희: 145
# Word 상대방: 145
# Word 미련: 145
# Word 잡기: 145
# Word 렉스킴: 145
# Word 모로: 145
# Word 용량: 145
# Word 학사: 145
# Word 프리: 144
# Word 어색: 144
# Word 요원: 144
# Word 복잡: 144
# Word 불안감: 144
# Word 모이: 144
# Word 갈팡질팡: 144
# Word 화이팅: 144
# Word 미용: 144
# Word 마디: 144
# Word 재고: 144
# Word 풀기: 144
# Word 이란희: 144
# Word 학폭: 144
# Word 치킨: 144
# Word 지정: 144
# Word 방황: 144
# Word 정장: 143
# Word 이미지: 143
# Word 데일: 143
# Word 고저: 143
# Word 생윤: 143
# Word 미도: 143
# Word 리신: 143
# Word 자국: 143
# Word 국제고: 143
# Word 삼성동: 143
# Word 소한: 143
# Word 학비: 143
# Word 제중: 143
# Word 발전: 143
# Word 집값: 143
# Word 공원: 143
# Word 바디: 143
# Word 오르고: 143
# Word 편의점: 143
# Word 매직: 143
# Word 분노: 143
# Word 용어: 142
# Word 탈락: 142
# Word 입학식: 142
# Word 사태: 142
# Word 하필: 142
# Word 폐지: 142
# Word 식품: 142
# Word 서초고: 142
# Word 일등급: 142
# Word 하나라: 142
# Word 가스: 142
# Word 어금니: 142
# Word 곧잘: 142
# Word 양가: 142
# Word 다시피: 142
# Word 리자: 142
# Word 솔로: 142
# Word 커플: 141
# Word 골드: 141
# Word 공진단: 141
# Word 수특: 141
# Word 라이브: 141
# Word 와이즈만: 141
# Word 쭈욱: 141
# Word 본문: 141
# Word 한복: 141
# Word 장기: 141
# Word 동료: 141
# Word 대상포진: 141
# Word 김밥: 141
# Word 커뮤니티: 141
# Word 용인외고: 141
# Word 투어: 141
# Word 화이트: 141
# Word 화면: 140
# Word 부디: 140
# Word 정수기: 140
# Word 압박: 140
# Word 트리: 140
# Word 무한: 140
# Word 수납: 140
# Word 테이블: 140
# Word 교차: 140
# Word 기보: 140
# Word 맘대로: 139
# Word 한장: 139
# Word mid: 139
# Word 양제: 139
# Word 쇼파: 139
# Word 출퇴근: 139
# Word 가늠: 139
# Word 도보: 139
# Word 가운: 139
# Word 다독: 139
# Word 시국: 139
# Word 거려: 139
# Word 손해: 139
# Word 쿠폰: 139
# Word 초등생: 139
# Word 지난해: 139
# Word 스마일: 139
# Word 이강: 139
# Word 준교쌤: 138
# Word 리조트: 138
# Word 오프라인: 138
# Word 쿠션: 138
# Word 인대: 138
# Word 적분: 138
# Word 자금: 138
# Word 설정: 138
# Word 불합: 138
# Word 와인: 138
# Word 신기: 138
# Word 구석: 138
# Word 부리: 138
# Word 빡빡: 138
# Word 직장인: 138
# Word 인턴: 138
# Word 긴장감: 137
# Word 무렵: 137
# Word 대중: 137
# Word 크리스마스: 137
# Word 수생: 137
# Word 하나로: 137
# Word 모드: 137
# Word 학전: 137
# Word 힐링: 137
# Word 일일: 137
# Word 어쨌든: 137
# Word 매트: 137
# Word 정해진: 137
# Word 산출: 137
# Word 취향: 137
# Word 시누이: 137
# Word 피자: 137
# Word 의합: 137
# Word 베스트: 137
# Word 파일: 137
# Word 고로: 137
# Word 교통: 136
# Word 한영외고: 136
# Word 수십: 136
# Word 의도: 136
# Word 예의: 136
# Word 옷장: 136
# Word 어버이날: 136
# Word 백만: 136
# Word 순수: 136
# Word 구문: 136
# Word 정규수: 136
# Word 팔자주름: 136
# Word 만들기: 136
# Word 영업: 136
# Word 이창무: 136
# Word 물리치료: 136
# Word sm: 136
# Word 하이퍼: 136
# Word 일간: 136
# Word 야자: 136
# Word 초견: 136
# Word 분해: 135
# Word 각오: 135
# Word 생리통: 135
# Word 처지: 135
# Word 관광: 135
# Word 자로: 135
# Word 팔고: 135
# Word 공항: 135
# Word 비누: 135
# Word 시범: 135
# Word 우성: 135
# Word 탄력: 135
# Word 변기: 135
# Word 세인: 135
# Word 써니: 135
# Word 치가: 135
# Word 리스트: 135
# Word 촬영: 135
# Word 한정: 135
# Word 월드: 135
# Word 간호사: 135
# Word 뜬금: 135
# Word 체험학습: 134
# Word 내달: 134
# Word 공신: 134
# Word 테니스: 134
# Word 질적: 134
# Word 지로: 134
# Word 입술: 134
# Word 방광염: 134
# Word 중년: 134
# Word 회정: 134
# Word 당분간: 134
# Word 교포: 134
# Word 수고: 134
# Word 사소: 134
# Word 두기: 134
# Word 양념: 134
# Word 검토: 134
# Word 동창: 134
# Word 비대: 134
# Word 원룸: 134
# Word 차지: 134
# Word 수련: 134
# Word 예술: 134
# Word 박하: 134
# Word 안경점: 133
# Word 분만: 133
# Word 중산: 133
# Word 포도: 133
# Word 이보: 133
# Word 다이슨: 133
# Word 향수: 133
# Word 대전: 133
# Word 계절: 133
# Word 오늘이: 133
# Word 안마: 133
# Word 식단: 133
# Word 신한: 133
# Word 경계: 133
# Word 목동: 133
# Word 수도권: 133
# Word 턱걸이: 133
# Word 보조: 132
# Word 기념: 132
# Word 시리: 132
# Word 전입: 132
# Word 남지: 132
# Word 조회: 132
# Word 국민연금: 132
# Word 화려: 132
# Word 손해광: 132
# Word 렉스: 132
# Word 발급: 132
# Word 계단: 132
# Word 여권: 132
# Word 구두: 132
# Word 차별: 132
# Word 명도: 132
# Word 임대: 132
# Word 증가: 132
# Word 대체로: 132
# Word 세척: 132
# Word 선수: 132
# Word 사랑니: 132
# Word 에센스: 131
# Word 골절: 131
# Word 속초: 131
# Word 한강: 131
# Word 용종: 131
# Word 사문: 131
# Word 폭발: 131
# Word 이맘: 131
# Word 운영자: 131
# Word 성문: 131
# Word 매력: 131
# Word 전교1등: 131
# Word 처분: 131
# Word 강의실: 131
# Word 연구소: 131
# Word 야말로: 131
# Word 합류: 130
# Word 결하: 130
# Word 을해: 130
# Word 이서: 130
# Word 중앙대: 130
# Word 아이방: 130
# Word 체질: 130
# Word 박세일: 130
# Word 용이: 130
# Word 교장: 130
# Word 아두: 130
# Word 이로: 130
# Word 남궁원: 130
# Word 한국어: 130
# Word 스파르타: 129
# Word 적정: 129
# Word 상문고: 129
# Word 베이스: 129
# Word 뒷바라지: 129
# Word 구축: 129
# Word 이슈: 129
# Word 사보: 129
# Word 로써: 129
# Word 호주: 129
# Word 하락: 129
# Word 역삼동: 129
# Word 스포츠: 129
# Word 진통제: 129
# Word 부원장: 129
# Word 안시: 129
# Word 도면: 129
# Word 이창희: 129
# Word 킬로: 129
# Word 하와이: 129
# Word 그땐: 129
# Word 교환: 129
# Word 토닝: 128
# Word 라떼: 128
# Word 여대생: 128
# Word 어르신: 128
# Word 강연: 128
# Word 샤넬: 128
# Word 시세: 128
# Word 이해도: 128
# Word 사우나: 128
# Word 패션: 128
# Word 잠신고: 128
# Word 사연: 128
# Word 표점: 128
# Word 송도: 128
# Word 린지: 127
# Word 생선: 127
# Word 달동: 127
# Word 토욜: 127
# Word 건만: 127
# Word 치기: 127
# Word 벡터: 127
# Word 인분: 127
# Word 초대: 127
# Word 음성: 127
# Word 시급: 127
# Word 성분: 127
# Word 재발: 127
# Word 덜컥: 127
# Word 관찰: 127
# Word 혈액: 127
# Word 다합: 127
# Word 고고: 127
# Word 회당: 127
# Word 서바이벌: 127
# Word 마켓: 127
# Word 에코: 127
# Word 초저: 127
# Word 발톱: 127
# Word 사도: 127
# Word 웃음: 127
# Word 기구: 127
# Word 반성: 126
# Word 무사: 126
# Word 폭력: 126
# Word 파리: 126
# Word 요기: 126
# Word 티셔츠: 126
# Word 기벡: 126
# Word 인식: 126
# Word 분리: 126
# Word 질환: 126
# Word 이글: 126
# Word 첨부: 126
# Word 고어: 126
# Word 연봉: 126
# Word 학벌: 126
# Word 싱글: 126
# Word 착각: 126
# Word 이아: 126
# Word 전원: 126
# Word 유학생: 126
# Word 전문대: 126
# Word 브라: 126
# Word 신건: 125
# Word 호불호: 125
# Word 통보: 125
# Word 후드: 125
# Word 몸살: 125
# Word 신기하: 125
# Word 이웃: 125
# Word 싸이트: 125
# Word 자락: 125
# Word 격려: 125
# Word 종은: 125
# Word 궁금증: 125
# Word 스텝: 125
# Word 코드: 125
# Word 번의: 125
# Word 불이익: 125
# Word 세팅: 125
# Word 인연: 125
# Word 리프: 125
# Word 보온: 125
# Word 보도: 125
# Word 정식: 125
# Word 지장: 125
# Word 메일: 125
# Word 덜덜: 125
# Word 동기부여: 124
# Word 매몰: 124
# Word 일해: 124
# Word 체형: 124
# Word 피로: 124
# Word 이과인: 124
# Word 뱃살: 124
# Word 지다: 124
# Word 슬리퍼: 124
# Word 클래식: 124
# Word 진급: 124
# Word 변별: 124
# Word 추세: 124
# Word 어젯밤: 124
# Word 해마: 124
# Word 리터: 124
# Word 여자친구: 124
# Word 문적: 124
# Word 살인: 124
# Word 회때: 124
# Word 모레: 124
# Word 박정인: 124
# Word 분량: 123
# Word 우지: 123
# Word 불친절: 123
# Word 독재: 123
# Word 용도: 123
# Word 불법: 123
# Word 필터: 123
# Word 둘이서: 123
# Word 경영학: 123
# Word 사나: 123
# Word 딸내미: 123
# Word 에고: 123
# Word 니거: 123
# Word 정착: 123
# Word 패턴: 123
# Word 프라이어: 123
# Word 소금: 122
# Word 입사: 122
# Word 수액: 122
# Word 송파구: 122
# Word 공무원: 122
# Word 가사: 122
# Word 전단지: 122
# Word 보인고: 122
# Word 신하: 122
# Word 특례: 122
# Word 자존심: 122
# Word 말끝: 122
# Word 지난달: 121
# Word 기웃: 121
# Word 복수: 121
# Word 주년: 121
# Word 숙박: 121
# Word 고모: 121
# Word 조오제: 121
# Word 발음: 121
# Word 간격: 121
# Word 규정: 121
# Word 중복: 121
# Word 기쁨: 121
# Word 사드: 121
# Word 독해력: 120
# Word 커트: 120
# Word 주네: 120
# Word 판정: 120
# Word 키시: 120
# Word 이십: 120
# Word 한우: 120
# Word 동부: 120
# Word 손목: 120
# Word 소홀: 120
# Word 조퇴: 120
# Word 선풍기: 120
# Word 균형: 120
# Word 저장: 120
# Word 대초: 120
# Word 분계: 120
# Word 아쉬움: 120
# Word 금리: 120
# Word 원피스: 119
# Word 긴지: 119
# Word 주니: 119
# Word 지우: 119
# Word 뚜껑: 119
# Word 나시: 119
# Word 찬찬: 119
# Word 미만: 119
# Word 현관: 119
# Word 타강: 119
# Word 비상: 119
# Word 제모: 119
# Word 뉴파인: 119
# Word 부지런: 119
# Word 절망: 119
# Word 수상실: 119
# Word 고객: 119
# Word 내부: 119
# Word 국산: 119
# Word 급여: 119
# Word 만남: 118
# Word 오로지: 118
# Word 안고: 118
# Word 당일치기: 118
# Word 폭탄: 118
# Word 과감: 118
# Word 정훈구: 118
# Word 아드님: 118
# Word 폴리: 118
# Word 빌딩: 118
# Word 명확: 118
# Word 부랴부랴: 118
# Word 발달: 118
# Word 발가락: 118
# Word 리버: 118
# Word 달전: 118
# Word 주저: 118
# Word 민중: 118
# Word 감고: 118
# Word 태풍: 118
# Word 서초동: 118
# Word 셀프: 118
# Word 치마: 118
# Word 김현정: 117
# Word 수영복: 117
# Word 빌라: 117
# Word 티파니: 117
# Word 요물: 117
# Word 사장: 117
# Word 바짝: 117
# Word 오일: 117
# Word 실천: 117
# Word 앞니: 117
# Word 난소: 117
# Word 시집: 117
# Word 배터리: 117
# Word 민감: 117
# Word 월간: 117
# Word 오피스텔: 117
# Word 실감: 117
# Word 드라이: 117
# Word 윤용균: 117
# Word 징징: 117
# Word 파마: 117
# Word 조급: 117
# Word 가로: 117
# Word 하든: 117
# Word 양성: 117
# Word 명중: 117
# Word 추기: 117
# Word 요사: 117
# Word 디딤돌: 117
# Word 못내: 116
# Word 서서히: 116
# Word 잡지: 116
# Word 김현옥: 116
# Word 내막: 116
# Word 선착순: 116
# Word 고인: 116
# Word 페이: 116
# Word 권해: 116
# Word 어딘가: 116
# Word 의존: 116
# Word 교과부: 116
# Word 하수: 116
# Word 강남대: 116
# Word 자유로: 115
# Word 대접: 115
# Word 새끼: 115
# Word 인걸: 115
# Word 퀴즈: 115
# Word 성질: 115
# Word 오구: 115
# Word 사자: 115
# Word 아주머니: 115
# Word 복도: 115
# Word 강박: 115
# Word 서너: 115
# Word 요금: 115
# Word 서브: 115
# Word 크라센: 115
# Word 영대: 115
# Word 원칙: 115
# Word 깜빡: 115
# Word 이제껏: 115
# Word 겨드랑이: 115
# Word 드뎌: 114
# Word 전인: 114
# Word 변동: 114
# Word 이식: 114
# Word tc: 114
# Word 알림: 114
# Word 수준별: 114
# Word 가루: 114
# Word 국영: 114
# Word 식기세척기: 114
# Word 간판: 114
# Word 잡티: 114
# Word 동반: 114
# Word 영재교육: 114
# Word 적금: 114
# Word 과잉: 114
# Word 깨끗: 114
# Word 실외: 113
# Word 동서: 113
# Word 가든: 113
# Word 계심: 113
# Word 꼬리: 113
# Word 제작: 113
# Word 학창시절: 113
# Word 잘해야: 113
# Word 발바닥: 113
# Word 캐슬: 113
# Word 편도: 113
# Word 지아: 113
# Word 출력: 113
# Word 경시관: 113
# Word 지원이: 113
# Word 윤리: 112
# Word 래대팰: 112
# Word 주인공: 112
# Word 방정식: 112
# Word 수건: 112
# Word 쌍둥이: 112
# Word 다정: 112
# Word 검정고시: 112
# Word 하향: 112
# Word 허용: 112
# Word 합리: 112
# Word 온도: 112
# Word 샐러드: 112
# Word 기차: 112
# Word 집합: 112
# Word 모처럼: 112
# Word 까르띠: 112
# Word 그다음: 111
# Word 안철우: 111
# Word 개발: 111
# Word 낮잠: 111
# Word 스테이: 111
# Word 집콕: 111
# Word 단백질: 111
# Word 소고기: 111
# Word 노출: 111
# Word 실컷: 111
# Word 거절: 111
# Word 철학: 111
# Word 가물: 111
# Word 연장: 111
# Word edu: 111
# Word 정독: 111
# Word 문제점: 111
# Word 도안: 111
# Word 사교육비: 111
# Word 면역: 111
# Word 혼하: 111
# Word 요미: 111
# Word 상대평가: 111
# Word 성장기: 111
# Word 오렌지: 111
# Word 페이지: 111
# Word 마더: 110
# Word 다함: 110
# Word 호기심: 110
# Word 항목: 110
# Word 정덕희: 110
# Word 헬스장: 110
# Word 인천: 110
# Word 유하: 110
# Word 흉터: 110
# Word 절대로: 110
# Word 일리: 110
# Word 온건: 110
# Word 의학: 110
# Word 우문: 110
# Word 풀다: 110
# Word 수년: 110
# Word 기네: 110
# Word 빈혈: 110
# Word 웃기: 110
# Word 라나: 110
# Word 소스: 110
# Word 제아: 110
# Word 딸도: 110
# Word 기업: 110
# Word 적극: 110
# Word 퇴사: 110
# Word 요시: 110
# Word 척추: 110
# Word 점차: 110
# Word 문화센터: 110
# Word 강점: 110
# Word 근교: 110
# Word 출혈: 109
# Word 반의: 109
# Word 고학: 109
# Word 오븐: 109
# Word 절친: 109
# Word 밴드: 109
# Word 큐브: 109
# Word 비롯: 109
# Word 필러: 109
# Word 마주: 109
# Word 그녀: 109
# Word 프레임: 109
# Word 울면: 109
# Word 손정우: 109
# Word 최악: 109
# Word 컬리: 109
# Word 애정: 109
# Word 닥터: 109
# Word 가세: 109
# Word 가전: 109
# Word 수수료: 109
# Word 해해: 109
# Word 기내: 109
# Word 도어: 109
# Word 합산: 108
# Word 스마트: 108
# Word 부로: 108
# Word 아산병원: 108
# Word 버릇: 108
# Word 카리스마: 108
# Word 거론: 108
# Word 단기간: 108
# Word 라섹: 108
# Word 무언가: 108
# Word 팔자: 108
# Word 만일: 108
# Word 고시: 108
# Word 가해: 108
# Word 뮤지컬: 108
# Word 트윈클: 108
# Word 분위: 108
# Word 조치: 108
# Word 경하: 108
# Word 식욕: 107
# Word 일차: 107
# Word 감안: 107
# Word 음달: 107
# Word 팬티: 107
# Word 아버: 107
# Word 피부관리: 107
# Word 큰소리: 107
# Word 나가요: 107
# Word 그레이: 107
# Word 학추: 107
# Word 크라운: 107
# Word 보험료: 107
# Word 가가: 107
# Word 재활: 107
# Word 서리: 107
# Word 육아: 107
# Word 절개: 107
# Word 직보: 107
# Word 상산고: 107
# Word 분다: 106
# Word 오버: 106
# Word 대여: 106
# Word 스벅: 106
# Word 부실: 106
# Word 조만간: 106
# Word 방해: 106
# Word 걸이: 106
# Word 제네시스: 106
# Word 선릉역: 106
# Word 세계사: 106
# Word 날인: 106
# ...
# Word 홍반: 1
# Word 천연자원: 1
# Word 방확: 1
# Word 김기식: 1
# Word 덮친격: 1
# Word 봄직: 1
# Word 동심: 1
# Word 린수: 1
# Word 외촐: 1
# Word 능데: 1
# Word 라크로스: 1
# Word 백팔번뇌: 1
# Word 섶벌: 1
# Word 생접: 1
# Word 김엉훈샘: 1
# Word 강창훈: 1
# Word 시스로: 1
# Word 량씩: 1
# Word 쿳션: 1
# Word 이윤복: 1
# Word 종규반: 1
# Word 강은교: 1
# Word 클레멘츠: 1
# Word 정규분포: 1
# Word 세로축: 1
# Word 번서: 1
# Word 에트: 1
# Word 공함: 1
# Word 당스: 1
# Word 폭하: 1
# Word 괴롭슴돠: 1
# Word 앤드루: 1
# Word 정정당당: 1
# Word 맘에듬: 1
# Word 도라지꽃: 1
# Word 써브: 1
# Word 산꿩: 1
# Word 간틈: 1
# Word 클렌저랑겔: 1
# Word 박상면: 1
# Word 꿀릴것: 1
# Word 박종유: 1
# Word 뿐집: 1
# Word 거른뒤: 1
# Word 만당: 1
# Word 레스텔: 1
# Word 나오믐: 1
# Word 다그다: 1
# Word 꽃피: 1
# Word 스핑: 1
# Word 조르르: 1
# Word 브누아: 1
# Word 오스카: 1
# Word 디맘선: 1
# Word 애둘셋: 1
# Word 후닥닥: 1
# Word 아사다마오: 1
# Word 날고기: 1
# Word 포노겐: 1
# Word 꾸즌: 1
# Word 알부민: 1
# Word 차셤: 1
# Word 박다솜: 1
# Word 자풀: 1
# Word 곽희: 1
# Word 수상학: 1
# Word 손말: 1
# Word 메뉴바: 1
# Word 벌썩: 1
# Word 얍삽: 1
# Word 폭풍우: 1
# Word 기태영: 1
# Word 앵두: 1
# Word 농로길: 1
# Word 에트왈입니: 1
# Word 아씨시: 1
# Word 청기: 1
# Word 안집: 1
# Word 년정: 1
# Word 셤이랍: 1
# Word 대중매체: 1
# Word 러줘: 1
# Word 드랍될: 1
# Word 뭉텡: 1
# Word 샘밖: 1
# Word 베린: 1
# Word 옌장: 1
# Word 후둑: 1
# Word 서양음악: 1
# Word 밥멕: 1
# Word 더숲: 1
# Word 한효순: 1
# Word 중남미: 1
# Word 두시만세: 1
# Word 아이러브유: 1
# Word 눌란것: 1
# Word 다여트한다: 1
# Word 쾌재: 1
# Word 왕조: 1
# Word 블로: 1
# Word 반디앤루니스: 1
# Word 곳그: 1
# Word 깡밥: 1
# Word 아카리: 1
# Word 꼽는다: 1
# Word 별루긴: 1
# Word 블로셔: 1
# Word 컴백홈: 1
# Word 봄산행: 1
# Word 여성시대: 1
# Word 크라제버거: 1
# Word 레벌중: 1
# Word 하일지: 1
# Word 져러스해: 1
# Word 려낭: 1
# Word 워맘: 1
# Word 엄정: 1
# Word 특품: 1
# Word 관고: 1
# Word 첫쨰: 1
# Word 한선수: 1
# Word 거립: 1
# Word 의키: 1
# Word 헤모글로빈: 1
# Word 금박: 1
# Word 도좀: 1
# Word 렀답니: 1
# Word 라스베이거스: 1
# Word 병주: 1
# Word 산악회: 1
# Word 입합: 1
# Word 윤샘반: 1
# Word 덮혔: 1
# Word 최예나: 1
# Word 재종때: 1
# Word 주실슈: 1
# Word 민안: 1
# Word 콘원: 1
# Word 무열왕릉: 1
# Word 토큰: 1
# Word 풀빵: 1
# Word 여거: 1
# Word 왔넹: 1
# Word 메드: 1
# Word 출입통제: 1
# Word 스프링보드: 1
# Word 말슴: 1
# Word 뛰어듭니: 1
# Word 뽀너스: 1
# Word 압학: 1
# Word 송쌤이시: 1
# Word 휘었네: 1
# Word 훈민정음: 1
# Word 편하덴데: 1
# Word 옆눈: 1
# Word 프라이데이: 1
# Word 염원: 1
# Word 겜방: 1
# Word 불교도: 1
# Word 로버: 1
# Word 박종필: 1
# Word 이가야: 1
# Word 최가영: 1
# Word 전인수: 1
# Word 뒷산: 1
# Word 도레미: 1
# Word 파솔: 1
# Word 길일: 1
# Word 센츠쪽: 1
# Word 귀빈: 1
# Word 더할껄: 1
# Word 토이저러스: 1
# Word 대화기: 1
# Word 어째어째: 1
# Word 바랬지: 1
# Word 가책: 1
# Word 이호성: 1
# Word 과이팅: 1
# Word 수피: 1
# Word 도날드: 1
# Word 파라과이: 1
# Word 젼하: 1
# Word 국민정부: 1
# Word 단사: 1
# Word 쫀다: 1
# Word 명국: 1
# Word 윤석호: 1
# Word 탱님: 1
# Word 깜깜무소식: 1
# Word 아열대: 1
# Word 크라이슬러: 1
# Word 미쟝센: 1
# Word 찬텍: 1
# Word 발렌타이데이: 1
# Word 브래니악: 1
# Word 네스타: 1
# Word 핸펀두: 1
# Word 디맘임글: 1
# Word 틱인것같: 1
# Word 머랍: 1
# Word 열대: 1
# Word 데핸폰: 1
# Word 임시직: 1
# Word 탑샘: 1
# Word 서훈: 1
# Word 애썻: 1
# Word 겆히: 1
# Word 혀뿌리: 1
# Word 송창식: 1
# Word 이장희: 1
# Word 장사익: 1
# Word 맘입: 1
# Word 륭합니: 1
# Word 페해: 1
# Word 관가: 1
# Word 오피러스: 1
# Word 스미스: 1
# Word 씨아이: 1
# Word 용상: 1
# Word 옭길: 1
# Word 수도위: 1
# Word 관게: 1
# Word 럭슬: 1
# Word 옭길려: 1
# Word 었길: 1
# Word 산란: 1
# Word 미치코: 1
# Word 차레: 1
# Word 파스파: 1
# Word 다빈: 1
# Word 자이라: 1
# Word 먹었쥬: 1
# Word 실폐율: 1
# Word 치루었는데: 1
# Word 어휴어: 1
# Word 사미인: 1
# Word 상장도: 1
# Word 돨까: 1
# Word 국가경쟁력: 1
# Word 국부: 1
# Word 고추전: 1
# Word 생선전: 1
# Word 이진숙: 1
# Word 한껀: 1
# Word 쥑었써: 1
# Word 겉모양: 1
# Word 빵나왔슈: 1
# Word 쓰럽기: 1
# Word 참아욤: 1
# Word 청나라: 1
# Word 다검: 1
# Word 김지혜: 1
# Word 무연: 1
# Word 터반: 1
# Word 추서: 1
# Word 진확: 1
# Word 보니펌: 1
# Word 최낙현: 1
# Word 계량기: 1
# Word 스산함: 1
# Word 콧줄끼: 1
# Word 요합반: 1
# Word 트름같은: 1
# Word 손놨었: 1
# Word 있늠: 1
# Word 광산업: 1
# Word 가드닝: 1
# Word 큐텐: 1
# Word 첩첩: 1
# Word 페매: 1
# Word 알부: 1
# Word 시덕: 1
# Word 비쌴것같: 1
# Word 셔용: 1
# Word 걸몇: 1
# Word 애견샵: 1
# Word 견사: 1
# Word 박부원: 1
# Word 최득: 1
# Word 계자: 1
# Word 냉탕: 1
# Word 꼬추: 1
# Word 언노운: 1
# Word 배틀넷: 1
# Word 관찰사: 1
# Word 혈중: 1
# Word 구케: 1
# Word 중역: 1
# Word 말임: 1
# Word 도초등: 1
# Word 샘집: 1
# Word 아이튠스: 1
# Word 타소: 1
# Word 옆짝: 1
# Word 역때: 1
# Word 국안: 1
# Word 으셨: 1
# Word 이박사: 1
# Word 그랜드피아노: 1
# Word 마분지: 1
# Word 됫다: 1
# Word 백산: 1
# Word 명력: 1
# Word 둥록: 1
# Word 마음의소리: 1
# Word 노블레스: 1
# Word 정열맨: 1
# Word 전자출판: 1
# Word 포스트스크립트: 1
# Word 운영체제: 1
# Word 깍쟁이: 1
# Word 무근: 1
# Word 학맥: 1
# Word 떼돈: 1
# Word 버시겠네: 1
# Word 볼새: 1
# Word 괞히: 1
# Word 프롱: 1
# Word 디맘댁: 1
# Word 이상무: 1
# Word 후직: 1
# Word 자는둥: 1
# Word 어무이: 1
# Word 이족: 1
# Word 닐맘: 1
# Word 홍시: 1
# Word 도친: 1
# Word 소냐: 1
# Word 컴겜임: 1
# Word 챤스: 1
# Word 쭙는: 1
# Word 화시: 1
# Word 학종맘: 1
# Word 민주공화국: 1
# Word 데결: 1
# Word 늦음: 1
# Word 정것: 1
# Word 토링: 1
# Word 스도쿠: 1
# Word 공안: 1
# Word 마술사: 1
# Word 베그: 1
# Word 샛길: 1
# Word 마린: 1
# Word 욱한건: 1
# Word 젤독스: 1
# Word 빙고게임: 1
# Word 피동: 1
# Word 벨로루시: 1
# Word 키즈나: 1
# Word 박왕식: 1
# Word 급편: 1
# Word 정기승: 1
# Word 찌찌: 1
# Word 데프: 1
# Word 퍼블릭스: 1
# Word 매그나: 1
# Word 커드: 1
# Word 퍼갔더: 1
# Word 뉴발뮤: 1
# Word 날걸: 1
# Word 옵터: 1
# Word 친자: 1
# Word 동경제: 1
# Word 엠을하: 1
# Word 싑다: 1
# Word 다녔드랬습니: 1
# Word 런징: 1
# Word 응답기: 1
# Word 바비인형: 1
# Word 해난구조대: 1
# Word 한연수: 1
# Word 돌댕: 1
# Word 얀함: 1
# Word 이기조: 1
# Word 부덤: 1
# Word 해공: 1
# Word 티샤: 1
# Word 한송: 1
# Word 괜챦으련: 1
# Word 쯤기: 1
# Word 휴고보스: 1
# Word 전자칠판: 1
# Word 결홀: 1
# Word 마지기: 1
# Word 끝나버: 1
# Word 허진: 1
# Word 밀리터리: 1
# Word 박준호: 1
# Word 곽상: 1
# Word 팅실: 1
# Word 셔론: 1
# Word 어쳐: 1
# Word 대인배: 1
# Word 런류: 1
# Word 플륫같: 1
# Word 제유: 1
# Word 미니홈피: 1
# Word 저휜: 1
# Word 화랑도: 1
# Word 배상철: 1
# Word 뿌니: 1
# Word 용떡: 1
# Word 귤등: 1
# Word 퉤퉤: 1
# Word 융해: 1
# Word 강희제: 1
# Word 나루토: 1
# Word 상지: 1
# Word 쌍윤: 1
# Word 인지상정: 1
# Word 팅이들: 1
# Word 셋팅되었: 1
# Word 술담: 1
# Word 정시연: 1
# Word 랍다: 1
# Word 세손: 1
# Word 솎아낼: 1
# Word 임인: 1
# Word 타자수: 1
# Word 목례: 1
# Word 차탈: 1
# Word 어케푸세: 1
# Word 괘찮을까: 1
# Word 병땜: 1
# Word 키랍니: 1
# Word 어째야: 1
# Word 뚤려있네: 1
# Word 업뎃되는: 1
# Word 설강화: 1
# Word 설강: 1
# Word 한소정: 1
# Word 어딧: 1
# Word 박정훈: 1
# Word 젠장: 1
# Word 데띵동: 1
# Word 맘들껜: 1
# Word 러친: 1
# Word 맹추: 1
# Word 셨었거든: 1
# Word 두었더랬: 1
# Word 뿜으: 1
# Word 컨버터: 1
# Word 생치: 1
# Word 는담: 1
# Word 권힘: 1
# Word 원운동: 1
# Word 스칸디나비아: 1
# Word 한맺힌듯해: 1
# Word 입벌: 1
# Word 못생: 1
# Word 정몇: 1
# Word 밴둥밴둥: 1
# Word 어데없: 1
# Word 키던: 1
# Word 쌤걸루: 1
# Word 데렉슬: 1
# Word 아강: 1
# Word 족탕: 1
# Word 쪽머: 1
# Word 퍼왔슈: 1
# Word 괜챃: 1
# Word 비개: 1
# Word 특례을: 1
# Word 건방병: 1
# Word 읊어주: 1
# Word 뽀듣: 1
# Word 아미타: 1
# Word 짓안: 1
# Word 남점: 1
# Word 상응: 1
# Word 과외활동: 1
# Word 성모송: 1
# Word 몰레이: 1
# Word 바때: 1
# Word 로건: 1
# Word 장수지: 1
# Word 족끼: 1
# Word 임에랴: 1
# Word 정성호: 1
# Word 눈썰매장: 1
# Word 종요: 1
# Word 소음정: 1
# Word 폭식증: 1
# Word 꼽는곳인줄: 1
# Word 몆개맞: 1
# Word 클로이: 1
# Word 려원: 1
# Word 젠나: 1
# Word 씨에스제이: 1
# Word 단두: 1
# Word 트레스: 1
# Word 떫뜨름: 1
# Word 그레이터: 1
# Word 난향: 1
# Word 꼽느: 1
# Word 후평: 1
# Word 안꼽아놨다: 1
# Word 둥제: 1
# Word 낸셜: 1
# Word 메릴랜드주: 1
# Word 빠빠이: 1
# Word 소다라: 1
# Word 탠디: 1
# Word 았는뎨: 1
# Word 훤쌤: 1
# Word 그린팩토리: 1
# Word 류성룡: 1
# Word 퍼머넌트: 1
# Word 덧문: 1
# Word 처붐: 1
# Word 월트: 1
# Word 록펠러: 1
# Word 쏀만풀: 1
# Word 상정: 1
# Word 석주: 1
# Word 어도비: 1
# Word 이상룡: 1
# Word 웅이: 1
# Word 운악: 1
# Word 허련: 1
# Word 건전성: 1
# Word 이상오: 1
# Word 팀수: 1
# Word 보크: 1
# Word 스벅쪽: 1
# Word 신호시: 1
# Word 꼬드깁니: 1
# Word 방종: 1
# Word 싸이버: 1
# Word 깡추: 1
# Word 위속: 1
# Word 맹글어: 1
# Word 던날: 1
# Word 어깨춤: 1
# Word 박즹: 1
# Word 태임: 1
# Word 어집: 1
# Word 애번: 1
# Word 알친: 1
# Word 해집: 1
# Word 장사치: 1
# Word 유유상종: 1
# Word 말그: 1
# Word 나왓드랫: 1
# Word 쨘합니: 1
# Word 얼매: 1
# Word 시켜버: 1
# Word 러쉬아워: 1
# Word 임펜: 1
# Word 수엊: 1
# Word 쑥쓰럽: 1
# Word 얼굴크기: 1
# Word 거덩: 1
# Word 홍석준: 1
# Word 포동포동: 1
# Word 덕임역: 1
# Word 크레파스: 1
# Word 판촉: 1
# Word 공처: 1
# Word 굴림: 1
# Word 들엇습니: 1
# Word 물고기방: 1
# Word 수정체: 1
# Word 단행: 1
# Word 순환계: 1
# Word 과주: 1
# Word 준교쌤글: 1
# Word 합집: 1
# Word 러집니: 1
# Word 현사: 1
# Word 과천시: 1
# Word 쉬웟다: 1
# Word 왕시: 1
# Word 뉘기: 1
# Word 유행병: 1
# Word 신문로: 1
# Word 리복: 1
# Word 메인보컬: 1
# Word 성씨: 1
# Word 김이랑: 1
# Word 장욱: 1
# Word 아시안컵: 1
# Word 보건부: 1
# Word 로터: 1
# Word 한동수: 1
# Word 리칸: 1
# Word 초등힉: 1
# Word 독립전쟁: 1
# Word 육일정: 1
# Word 나산: 1
# Word 자남: 1
# Word 해서체: 1
# Word 미죄: 1
# Word 필라멘트: 1
# Word 급비: 1
# Word 탈선: 1
# Word 집채: 1
# Word 것습니: 1
# Word 린정: 1
# Word 남아프리카공화국: 1
# Word 일간신문: 1
# Word 국증: 1
# Word 코크: 1
# Word 윤빛가람: 1
# Word 결슬공: 1
# Word 뤘던: 1
# Word 었던걸까: 1
# Word 쇠붙이: 1
# Word 위에롱패딩: 1
# Word 얼뗘: 1
# Word 굴립니: 1
# Word 특설: 1
# Word 멜트가없: 1
# Word 사진올리기: 1
# Word 골문: 1
# Word 어드벤쳐: 1
# Word 해얄텐데: 1
# Word 중힉교: 1
# Word 황자: 1
# Word 구자: 1
# Word 옹정제: 1
# Word 니콜라예프: 1
# Word 줄어듬: 1
# Word 정보사회: 1
# Word 꼴라쥬: 1
# Word 파븀: 1
# Word 이미연: 1
# Word 향수병: 1
# Word 개함: 1
# Word 잘썻는데: 1
# Word 명휘문: 1
# Word 세습: 1
# Word 턱산: 1
# Word 총격: 1
# Word 재임: 1
# Word 꿀릴: 1
# Word 법정공휴일: 1
# Word 이용대: 1
# Word 시격: 1
# Word 님직강반: 1
# Word 널럴할것: 1
# Word 라테: 1
# Word 훠이훠이: 1
# Word 해중: 1
# Word 게신: 1
# Word 레져비: 1
# Word 펑나: 1
# Word 난바역: 1
# Word 다닌느것: 1
# Word 수늠: 1
# Word 손볼: 1
# Word 바슷: 1
# Word 연모: 1
# Word 쉬울런지: 1
# Word 아카펠라: 1
# Word 년컷: 1
# Word 멜라닌: 1
# Word 텔런트: 1
# Word 환겨: 1
# Word 랬습니: 1
# Word 테세우스: 1
# Word 액티브한거: 1
# Word 형차: 1
# Word 쭉풀: 1
# Word 트앞: 1
# Word 애표: 1
# Word 애려: 1
# Word 과단: 1
# Word 베이비페이스: 1
# Word 홰외: 1
# Word 랭스: 1
# Word 특허청: 1
# Word 거울쓰기: 1
# Word 껄끄러: 1
# Word 신파: 1
# Word 휑하: 1
# Word 요티: 1
# Word 고병헌: 1
# Word 극히평: 1
# Word 렇게듣: 1
# Word 후련: 1
# Word 웠던거: 1
# Word 황금시간대: 1
# Word 거슬러가: 1
# Word 원내대표: 1
# Word 대순: 1
# Word 청협: 1
# Word 코롱: 1
# Word 임태희: 1
# Word 대통령실장: 1
# Word 백용호: 1
# Word 김무성: 1
# Word 토안: 1
# Word 트함: 1
# Word 객체: 1
# Word 농심: 1
# Word 단층: 1
# Word 속기: 1
# Word 었음다: 1
# Word 욱욱: 1
# Word 관쪽: 1
# Word 요질: 1
# Word 딸친: 1
# Word 돤건: 1
# Word 어책들: 1
# Word 렸구: 1
# Word 애완: 1
# Word 다녔느데: 1
# Word 문학자: 1
# Word 땀찰때: 1
# Word 닥으: 1
# Word 말레: 1
# Word 보건학: 1
# Word 끼끼: 1
# Word 씌어놓: 1
# Word 리화: 1
# Word 려강: 1
# Word 이스포츠: 1
# Word 변일: 1
# Word 전혜선: 1
# Word 남엘만: 1
# Word 컴겜: 1
# Word 보컬리스트: 1
# Word 뻘들: 1
# Word 패킷: 1
# Word 송신: 1
# Word 애달: 1
# Word 항공우편: 1
# Word 비비큐: 1
# Word 구아바: 1
# Word 클린앤클리어: 1
# Word 나을읏: 1
# Word 꿀팀: 1
# Word 고추기름: 1
# Word 유마: 1
# Word 솔리스트: 1
# Word 복시: 1
# Word 달랍: 1
# Word 양안: 1
# Word 옥주현: 1
# Word 얼핏들: 1
# Word 않을껄: 1
# Word 의학용어: 1
# Word 아래한글: 1
# Word 대성당: 1
# Word 왕위계승: 1
# Word 석공: 1
# Word 스뽜르따: 1
# Word 헐랭: 1
# Word 버둥거려봐: 1
# Word 박소희: 1
# Word 월든: 1
# Word 쳤슈: 1
# Word 금욜일: 1
# Word 쌍해: 1
# Word 데꺄: 1
# Word 일본열도: 1
# Word 방송사고: 1
# Word 피난소: 1
# Word 닝닝: 1
# Word 다운링크: 1
# Word 설일: 1
# Word 이혜승: 1
# Word 용제: 1
# Word 술렁: 1
# Word 혈관주사: 1
# Word 마가루: 1
# Word 사이비종교: 1
# Word 김웅용: 1
# Word 기네스북: 1
# Word 핏대: 1
# Word 서흥: 1
# Word 업그: 1
# Word 하급생: 1
# Word 타조: 1
# Word 한용운: 1
# Word 좀놀: 1
# Word 씨버: 1
# Word 분제: 1
# Word 르고닳: 1
# Word 가리발디: 1
# Word 탁구공: 1
# Word 창제: 1
# Word 아테네올림픽: 1
# Word 종내: 1
# Word 비뇨기관: 1
# Word 준정: 1
# Word 텔방: 1
# Word 탈영: 1
# Word 중헌: 1
# Word 증평: 1
# Word 유인촌: 1
# Word 테츠: 1
# Word 그르나: 1
# Word 자습: 1
# Word 버러지: 1
# Word 거린답니: 1
# Word 모리셔스: 1
# Word 앙코르왓: 1
# Word 난게: 1
# Word 터린: 1
# Word 은달: 1
# Word 람세스: 1
# Word 엠보: 1
# Word 춘추전국시대: 1
# Word 김장현: 1
# Word 질초: 1
# Word 랫배: 1
# Word 힘이겟: 1
# Word 에이전시: 1
# Word 재빨: 1
# Word 쪼니: 1
# Word 빨기: 1
# Word 베딩: 1
# Word 이솝우화: 1
# Word 메릿있다: 1
# Word 발부리: 1
# Word 햄셋트: 1
# Word 굳어버: 1
# Word 그라데이션: 1
# Word 쉭쉭: 1
# Word 멸시: 1
# Word 주착: 1
# Word 수집광: 1
# Word 빼뜨뤼스: 1
# Word 율면: 1
# Word 김은하: 1
# Word 생홀: 1
# Word 오믈렛: 1
# Word 짐심: 1
# Word 씨지브이: 1
# Word 왜내: 1
# Word 신은채: 1
# Word 조태환: 1
# Word 닌다고했: 1
# Word 들락이: 1
# Word 박일경: 1
# Word 개일때: 1
# Word 자피: 1
# Word 괜챦던: 1
# Word 일특: 1
# Word 권하셧답니: 1
# Word 픽어: 1
# Word 서스펜션: 1
# Word 적색: 1
# Word 덴노: 1
# Word 일왕: 1
# Word 섬나라: 1
# Word 식용: 1
# Word 사이버영재: 1
# Word 짤릴까: 1
# Word 를쿵: 1
# Word 핫소스: 1
# Word 가묘: 1
# Word 겠습니꽈: 1
# Word 하치: 1
# Word 안디: 1
# Word 사이보그: 1
# Word 냄왈: 1
# Word 깝기: 1
# Word 블렉홀속: 1
# Word 딸바보: 1
# Word 었었나봐: 1
# Word 꼬매야한다: 1
# Word 뒤엉킨: 1
# Word 남녀평등: 1
# Word 업뎃할: 1
# Word 또뭐: 1
# Word 베세토: 1
# Word 코스모: 1
# Word 용처: 1
# Word 장학퀴즈: 1
# Word 택길입니: 1
# Word 권영진: 1
# Word 손장난: 1
# Word 레즈: 1
# Word 표어: 1
# Word 아카테밋: 1
# Word 철갑: 1
# Word 슴일: 1
# Word 쓰럽네: 1
# Word 백로: 1
# Word 꽃다지: 1
# Word 오염원: 1
# Word 염습: 1
# Word 무척추동물: 1
# Word 군락: 1
# Word 흑두루미: 1
# Word 저어새: 1
# Word 여종: 1
# Word 개불알풀: 1
# Word 홍현주: 1
# Word 때땐: 1
# Word 활성탄: 1
# Word 우릿돈: 1
# Word 쩡할: 1
# Word 꽃나무: 1
# Word 벚나무: 1
# Word 봄나물: 1
# Word 병후: 1
# Word 마키아벨리즘: 1
# Word 경제원: 1
# Word 시험관아기: 1
# Word 밟힌다: 1
# Word 특수상대성이론: 1
# Word 목원: 1
# Word 맛공: 1
# Word 김범진: 1
# Word 김양: 1
# Word 컴보: 1
# Word 독사: 1
# Word 까르띠에: 1
# Word 식목일: 1
# Word 치킨게임: 1
# Word 로체스터: 1
# Word 십종: 1
# Word 알파스: 1
# Word 탑번: 1
# Word 심부: 1
# Word 피자치즈: 1
# Word 자얄텐데: 1
# Word 회양목: 1
# Word 참가인: 1
# Word 스캣: 1
# Word 패션후르츠: 1
# Word 뉴론틴: 1
# Word 펜틴: 1
# Word 어델: 1
# Word 심선택: 1
# Word 야산: 1
# Word 호박속: 1
# Word 쇠뜨기: 1
# Word 양치식물: 1
# Word 홀씨: 1
# Word 솔잎: 1
# Word 호남선: 1
# Word 포트만: 1
# Word 김태원: 1
# Word 고선지: 1
# Word 중급: 1
# Word 디퍼런트: 1
# Word 생태학: 1
# Word 힘자랑: 1
# Word 얼리어답터: 1
# Word 바로다: 1
# Word 궁금궁: 1
# Word 팽팽돌: 1
# Word 못하랴: 1
# Word 말술이셨: 1
# Word 문화상: 1
# Word 허지만: 1
# Word 셋맘: 1
# Word 과탐은느긋: 1
# Word 어연: 1
# Word 차폭감: 1
# Word 독일어권: 1
# Word 눈총: 1
# Word 복제인간: 1
# Word 뚜껌: 1
# Word 단심: 1
# Word 유막: 1
# Word 쾌척: 1
# Word 재일교포: 1
# Word 김민환: 1
# Word 첩국: 1
# Word 횡렬: 1
# Word 초피: 1
# Word 발수: 1
# Word 폐션쇼: 1
# Word 제단: 1
# Word 케꽃: 1
# Word 제비꽃: 1
# Word 물망초: 1
# Word 꽃마리: 1
# Word 별꽃: 1
# Word 네발나비: 1
# Word 열우당: 1
# Word 행저: 1
# Word 엎질러: 1
# Word 리표: 1
# Word 플륫렛슨: 1
# Word 청경채: 1
# Word 바이올렛: 1
# Word 게저: 1
# Word 쩔뚝쩔뚝: 1
# Word 사일런트: 1
# Word 괜한거: 1
# Word 플륫하: 1
# Word 유행가: 1
# Word 성찬례: 1
# Word 징고: 1
# Word 막대그래프: 1
# Word 바랬습니: 1
# Word 독음: 1
# Word 어락: 1
# Word 희님: 1
# Word 과학기술부: 1
# Word 비례대표: 1
# Word 뇌염: 1
# Word 설리반: 1
# Word 늑막: 1
# Word 하는덴데: 1
# Word 까웠었는데: 1
# Word 꽃필: 1
# Word 인쪽: 1
# Word 소켓: 1
# Word 자살률: 1
# Word 꽃내음: 1
# Word 엎었지: 1
# Word 폐식: 1
# Word 번고: 1
# Word 상겹살: 1
# Word 회일: 1
# Word 힐수: 1
# Word 짠맛: 1
# Word 카뱅때: 1
# Word 포슬: 1
# Word 덜그락: 1
# Word 롭되: 1
# Word 돌격: 1
# Word 임계점: 1
# Word 존립: 1
# Word 중심선: 1
# Word 모선: 1
# Word 출항: 1
# Word 고기잡이: 1
# Word 해얄거같아: 1
# Word 으레: 1
# Word 띠신: 1
# Word 과샘: 1
# Word 뒤저: 1
# Word 듯폭망: 1
# Word 난파: 1
# Word 땟목: 1
# Word 섬쪽: 1
# Word 테주: 1
# Word 까브: 1
# Word 쟈켓울: 1
# Word 다래: 1
# Word 다만세: 1
# Word 마거릿: 1
# Word 스톨: 1
# Word 랜덤하우스: 1
# Word 생활성서: 1
# Word 이형진: 1
# Word 이지성: 1
# Word 방좀: 1
# Word 부검: 1
# Word 크리처: 1
# Word 남면: 1
# Word 할텔데: 1
# Word 거였슴돠: 1
# Word 절대다수: 1
# Word 온라인게임: 1
# Word 탈차: 1
# Word 에그림: 1
# Word 가르시아: 1
# Word 비피: 1
# Word 다피엠: 1
# Word 피구왕통키: 1
# Word 은장이: 1
# Word 씨트지: 1
# Word 칭합: 1
# Word 질약: 1
# Word 버럴: 1
# Word 층수: 1
# Word 뮈어때: 1
# Word 아문: 1
# Word 최성애: 1
# Word 땀방울: 1
# Word 최은숙: 1
# Word 편배: 1
# Word 김온유: 1
# Word 옥결: 1
# Word 코이케: 1
# Word 부키: 1
# Word 셤볼땐: 1
# Word 풀약: 1
# Word 런말: 1
# Word 됐슴돠: 1
# Word 백악: 1
# Word 진경산수: 1
# Word 대체휴일: 1
# Word 떡뽁기: 1
# Word 형췌관: 1
# Word 삼청: 1
# Word 소격: 1
# Word 어낸: 1
# Word 격언: 1
# Word 흠샘: 1
# Word 그르건: 1
# Word 메밀전: 1
# Word 잔칫집: 1
# Word 삼동: 1
# Word 율현동: 1
# Word 체부동: 1
# Word 언먹여: 1
# Word 빠우저: 1
# Word 텐진: 1
# Word 논조: 1
# Word 인문학상: 1
# Word 이은경: 1
# Word 꼰다: 1
# Word 푸마: 1
# Word 과핟: 1
# Word 윤수정: 1
# Word 음공: 1
# Word 브니크성: 1
# Word 발칸반도: 1
# Word 송곳: 1
# Word 지구별: 1
# Word 이인근: 1
# Word 가렵습니: 1
# Word 회음부: 1
# Word 효우: 1
# Word 넣어얄: 1
# Word 펌을하: 1
# Word 앞전: 1
# Word 체시스: 1
# Word 아방가르드: 1
# Word 똥망: 1
# Word 말또: 1
# Word 관철: 1
# Word 쌤이셨다: 1
# Word 마애불: 1
# Word 최흥재: 1
# Word 옴작: 1
# Word 토종닭: 1
# Word 음메: 1
# Word 엘리시움: 1
# Word 셤쳐봤지: 1
# Word 스포츠토토: 1
# Word 화성인: 1
# Word 오포읍: 1
# Word 찍었더랬: 1
# Word 사이공: 1
# Word 유림: 1
# Word 산꽃: 1
# Word 절절이: 1
# Word 진직: 1
# Word 명연기: 1
# Word 손소독: 1
# Word 셧었: 1
# Word 집대성: 1
# Word 화방: 1
# Word 인터가: 1
# Word 최용희: 1
# Word 후포: 1
# Word 보탬니: 1
# Word 굶는격: 1
# Word 때부텀: 1
# Word 빡쌔다: 1
# Word 도박중독: 1
# Word 김주성: 1
# Word 코리아닷컴: 1
# Word 스피킹원: 1
# Word 칭했던: 1
# Word 빡센학: 1
# Word 류준열: 1
# Word 수사반장: 1
# Word 헬헬: 1
# Word 둘밑: 1
# Word 금미: 1
# Word 류준: 1
# Word 왔는뎁쇼: 1
# Word 웅얼거림: 1
# Word 신신애: 1
# Word 예식: 1
# Word 효수: 1
# Word 아라레: 1
# Word 치타: 1
# Word 법문사: 1
# Word 식이섬유: 1
# Word 쇼케: 1
# Word 소니: 1
# Word 려감: 1
# Word 뜨는둥: 1
# Word 옃억씩: 1
# Word 모둠발: 1
# Word 한컴오피스: 1
# Word 패가망신: 1
# Word 번덕: 1
# Word 탈잉: 1
# Word 멜로드라마: 1
# Word 창얼: 1
# Word 계륜미: 1
# Word 선지국: 1
# Word 썰전: 1
# Word 끄러웠: 1
# Word 윌팩: 1
# Word 비프: 1
# Word 비첸: 1
# Word 선빵: 1
# Word 빠듯하거: 1
# Word 후경: 1
# Word 분자식: 1
# Word 사군자: 1
# Word 노컷: 1
# Word 빡꽁: 1
# Word 분감: 1
# Word 대댜: 1
# Word 용범: 1
# Word 도속: 1
# Word 첨언할: 1
# Word 영남권: 1
# Word 도셨다: 1
# Word 연구개발: 1
# Word 개과천선: 1
# Word 스믈스믈: 1
# Word 상괸: 1
# Word 심은경: 1
# Word 발대식: 1
# Word 정적분: 1
# Word 부정정: 1
# Word 전략기획: 1
# Word 지식경제: 1
# Word 날보: 1
# Word 러지므: 1
# Word 단삼: 1
# Word 때부타: 1
# Word 도각: 1
# Word 왈패: 1
# Word 주먹다짐: 1
# Word 팻트병: 1
# Word 러다닐때: 1
# Word 취나물: 1
# Word 자내아: 1
# Word 롭지못: 1
# Word 목멱산: 1
# Word 아동문학: 1
# Word 린드그렌: 1
# Word 비스크: 1
# Word 스티그: 1
# Word 스텐후: 1
# Word 궁금밤: 1
# Word 람바다: 1
# Word 뱡원: 1
# Word 듀꺼: 1
# Word 더블체크: 1
# Word 센다이: 1
# Word 측만: 1
# Word 떠드: 1
# Word 은시계: 1
# Word 발금: 1
# Word 컨스털: 1
# Word 쫄티: 1
# Word 부글거림: 1
# Word 스벅글: 1
# Word 뚤릴까: 1
# Word 장량: 1
# Word 호르면: 1
# Word 더빨: 1
# Word 냉채: 1
# Word 인극: 1
# Word 춘하: 1
# Word 지펠: 1
# Word 히로: 1
# Word 신야: 1
# Word 마울: 1
# Word 체팅: 1
# Word 아이샤: 1
# Word 붇기: 1
# Word 문릿: 1
# Word 눈거플: 1
# Word 모자이크: 1
# Word 치어스: 1
# Word 태유바: 1
# Word 뭉큼: 1
# Word 오세민: 1
# Word 때제: 1
# Word 지쳐버: 1
# Word 것로: 1
# Word 황성수: 1
# Word 및저: 1
# Word 하실턴데: 1
# Word 도회지: 1
# Word 빡돌: 1
# Word 독일말: 1
# Word 중국말: 1
# Word 공업고등학교: 1
# Word 슬의생때: 1
# Word 신현빈: 1
# Word 하니지: 1
# Word 즉흥극: 1
# Word 닌듯: 1
# Word 디브이: 1
# Word 송쓰: 1
# Word 시었: 1
# Word 태문: 1
# Word 감축된: 1
# Word 황지역: 1
# Word 전자상거래: 1
# Word 마이크로로봇: 1
# Word 나마스: 1
# Word 장편: 1
# Word 리배: 1
# Word 엽전: 1
# Word 택리지: 1
# Word 질땐: 1
# Word 직경: 1
# Word 딩크였: 1
# Word 펌할까: 1
# Word 알콩방: 1
# Word 랑딸랑: 1
# Word 송월타올: 1
# Word 번영: 1
# Word 탐앤탐스라던: 1
# Word 어쩌란건: 1
# Word 로부: 1
# Word 지주시: 1
# Word 뭐던: 1
# Word 라파: 1
# Word 뽁긔: 1
# Word 심청가: 1
# Word 아라비안나이트: 1
# Word 아큐정전: 1
# Word 취함: 1
# Word 바랑: 1
# Word 홍쌤반: 1
# Word 캐스: 1
# Word 핫년때: 1
# Word 됏으: 1
# Word 헛웃: 1
# Word 괘얀타: 1
# Word 샹하이: 1
# Word 압록강: 1
# Word 잡미: 1
# Word 상함: 1
# Word 팻트: 1
# Word 뒷꽁지: 1
# Word 소송비용: 1
# Word 모토롤라: 1
# Word 두경부: 1
# Word 먼먼: 1
# Word 달채: 1
# Word 토산물: 1
# Word 떳길: 1
# Word 구지가: 1
# Word 규중: 1
# Word 쟁론: 1
# Word 금수회의록: 1
# Word 난쟁이: 1
# Word 하셧습니: 1
# Word 꼭곡: 1
# Word 병인양요: 1
# Word 외규장각: 1
# Word 의궤: 1
# Word 프지않: 1
# Word 괜챦았: 1
# Word 헤져: 1
# Word 란책: 1
# Word 온스타일: 1
# Word 어져있: 1

# %%
model.train(tagged_data, total_examples=model.corpus_count, epochs=model.epochs)

# %%
# get_vector 함수는 기존과 동일
def get_vector(model, item_idx):
    try:
        return model.docvecs[item_idx] #서 식별자(item_idx)에 해당하는 벡터를 모델에서 추출하는 역할
    except KeyError:
        return None  # 해당 키가 없을 경우 None 반환
    


# 모델이 순수 숫자 문자열 태그를 사용하므로, 'item_idx'만을 사용하여 벡터 검색
df['vector'] = df.apply(lambda row: get_vector(model, str(row['item_idx'])) if row['combined'] else None, axis=1)

# vector_df 생성 시에도 동일한 방식 적용
vector_df = pd.DataFrame({
    'item_idx': df['item_idx'],
    # 여기서도 'item_idx'만을 사용하여 벡터 검색
    'vector': df.apply(lambda row: get_vector(model, str(row['item_idx'])) if row['combined'] else None, axis=1)
})

print(vector_df)

#combined를 벱터화한것
# Out:
# /var/folders/xz/5z38xhnx3798ywm68t1fzzd40000gn/T/ipykernel_33272/283797180.py:4: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   return model.docvecs[item_idx] #서 식별자(item_idx)에 해당하는 벡터를 모델에서 추출하는 역할
#         item_idx                                             vector
# 0           4561  [0.6086013, 0.47499812, -0.26751295, -0.116748...
# 1           5684  [0.39927167, -0.34114057, -0.73800105, 0.56053...
# 2            191  [-0.0073037115, -0.2437775, 0.25304675, 0.7326...
# 3           7408  [0.3709748, 0.50565994, -1.1514426, 0.04925793...
# 4           8194  [-0.5066662, 0.007347686, 0.16918911, 1.210750...
# ...          ...                                                ...
# 122440    545008  [1.1912905, 0.058996793, -0.206127, 0.43094155...
# 122441    544947  [-0.21351588, -0.18485914, -0.37671673, -0.072...
# 122442    544919  [0.27543083, 0.64377177, -0.079306595, 0.53197...
# 122444    545102  [-0.18672772, -0.20815891, -0.27428073, -0.264...
# 122445    545095  [0.021963049, 0.57581437, -0.6052079, 0.650434...
#
# [82119 rows x 2 columns]

# %%
num_of_vectors = vector_df['vector'].notna().sum()
print(f"The total number of items with vectors: {num_of_vectors}")
# Out:
# The total number of items with vectors: 82119

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
 #유사도 계산
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np   #numpy : 파이썬 수치 연산 라이브러리

# %%
# 데이터 프레임에서 item_idx가 query_item_idx와 일치하는 행을 찾고 해당 행의 벡터 열 값 반환 
def get_query_vector(df, query_item_idx):
    # 일치하는 행 찾기 
    query_vector = df[df['item_idx'] == query_item_idx]['vector'].values
    # 해당 행의 'vector'열 값 가져오기
    return query_vector[0] if len(query_vector) > 0 else None

# 함수
def recommend_similar_items(query_item_idx, df, top_n=5):
    # 쿼리 아이템의 벡터 가져오기
    query_vector = get_query_vector(df, query_item_idx)
    if query_vector is None:
        return None  # 쿼리 아이템의 벡터를 찾을 수 없는 경우

    # 콘텐츠가 있는 아이템만 선택하여 벡터 추출하고 차원을 확인
    valid_items = df[df['contents'].notnull()]
    valid_vectors = valid_items['vector'].tolist()

    # 유효한 벡터만 선택하여 128차원 벡터만 추출
    valid_vectors_128 = [v for v in valid_vectors if v is not None and len(v) == 128]

    # 리스트 형태의 벡터를 NumPy 배열로 변환 (변환해야 계산 가능)
    item_vectors = np.array(valid_vectors_128)

    # 코사인 유사도 계산
    similarity_scores = cosine_similarity([query_vector], item_vectors)
    similarity_scores = similarity_scores[0]  # 2D 배열을 1D로 변환

    # 유사도 기준으로 상위 N개 아이템 인덱스 추출 (쿼리 아이템 제외)
    similar_items_idx = sorted(range(len(similarity_scores)), key=lambda i: similarity_scores[i], reverse=True)[:top_n]
    
    # 추천 아이템 정보 출력
    recommended_items = valid_items.iloc[similar_items_idx][['item_idx', 'vector', 'contents']]
    recommended_items['similarity'] = similarity_scores[similar_items_idx]

    return recommended_items

# %%
# 사용 예시
query_item_idx = 7408
   # 예시
recommendations = recommend_similar_items(query_item_idx, df)
print(recommendations)
# Out:
#        item_idx                                             vector  \
# 3          7408  [0.3709748, 0.50565994, -1.1514426, 0.04925793...
# 89702    495708  [-0.041794106, -0.03668289, -0.36488253, 0.068...
# 76222    463425  [0.054472964, 0.04377276, -0.04709559, -0.2215...
# 65262    417444  [0.30552524, 0.55082816, -0.42337686, 0.386309...
# 498        7796  [0.70549226, 0.9539472, -0.07447567, -0.596695...
#
#                                                 contents  similarity
# 3      예비중1 이안어학원에 대한 들리는 평판이 좋기도 했고, 또 마침 아이시간표 조절할일...    1.000000
# 89702  아이가 다니는 PEAI 학원에서 겨울방학 특강처럼 CRD 인문고전 특강모용상 원장님...    0.457796
# 76222  ILE중등 주 2회반은 1회 수업 시간이 어떻게되나요? 3시간 정도 되는지요? 1회...    0.440393
# 65262  예비 중1 입니다 청담 이글 다니다가 도저히 writing 못하겠다해서 그만두고,최...    0.439642
# 498    ILE 다닌지 1년된 예비 초6 엄마입니다.일반적으로, 예비초4에 청담 par라면 ...    0.434962

# %%
#엘라스틱서치 접속 설치
# %pip install elasticsearch
# Out:
# Requirement already satisfied: elasticsearch in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (8.11.1)
# Requirement already satisfied: elastic-transport<9,>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from elasticsearch) (8.11.0)
# Requirement already satisfied: urllib3<3,>=1.26.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from elastic-transport<9,>=8->elasticsearch) (2.1.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from elastic-transport<9,>=8->elasticsearch) (2023.11.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
from elasticsearch import Elasticsearch
from elasticsearch.helpers import bulk
from elasticsearch import helpers

# %%
# df는 데이터프레임, 'item_idx'와 'd2v_vector' 필드
data_for_es = [
    {   "_op_type": "update",  # update 하면 새롭게 안하고 업데이트 
        "_index": "items1", #문서가 속할 인덱스
        "_id": str(row['item_idx']),
        "doc": {
            "d2v_vector": [float(value) for value in row['vector']] if row['vector'] is not None else None
            # 'd2v_vector' 필드에 대한 값을 리스트로 제공
        }
    }
    for idx, row in df.iterrows()
    if row['vector'] is not None
]

# %%
# Elasticsearch 연결
es = Elasticsearch(hosts=[{'host': 'my-deployment-5d8a0f.es.us-east-1.aws.found.io', 'port': 9243,'scheme': 'https'}],
                  basic_auth=('elasticuser', 'hy%^&2022',),request_timeout=120)
#timeout: 서버에 요청이 완료될 때까지 더 많으 시간 부여

# %%
# bulk를 사용하여 데이터를 한 번에 업로드
#데이터 색인화
helpers.bulk(es, data_for_es,chunk_size=500)
# Out:
# (82119, [])
